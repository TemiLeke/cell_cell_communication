# %%
import os
import logging
import warnings
import itertools
import numpy as np
import scanpy as sc
import pandas as pd
from gsva_prep import prep_gsva
from itertools import chain
from functions import helper_functions
# Out:
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## **Data Prep Parameters**
#
# - `map_meta`: Indicates if metadata mapping is required for `pathology.group`. If set to False, `pathology.group` must exist in `adata.obs`
#
# - `test_names`: List of the different test names of interest.
#
# - `save_prefix`: Preferred prefix for saving critical files. Ideally chosen to be in the format `{source name}_{brain region}`. e.g `mathys_pfc`
#
# - `subject_id`: Column name for Subject/Patient ID in both metadata and `.obs`

# %%
save_prefix = 'seaad_mtg'                           # this takes the format '{StudyName}_{ThreeLetterAccronymForBrainRegion}'
subject_id = 'Donor ID'  
cell_type_column = 'Subclass'                       # 'Supertype (non-expanded)', 'Subclass'
region_name = save_prefix.split('_')[-1].upper()

data_dir = f'/media/tadeoye/Volume1/data/seq/SEA-AD/{region_name}/RNAseq/counts'

subclass = {
    'excitatory': ['L5 IT', 'L2/3 IT', 'L4 IT', 'L6 IT', 'L6 IT Car3', 'L5/6 NP', 'L6b', 'L6 CT', 'L5 ET'],
    'inhibitory': ['Pvalb', 'Sst', 'Lamp5 Lhx6', 'Vip', 'Lamp5', 'Sncg', 'Chandelier', 'Sst Chodl', 'Pax6'],
    'astrocyte': ['Astrocyte'],
    'microglia': ['Microglia-PVM'],
    'opc': ['OPC'],
    'oligodendrocyte': ['Oligodendrocyte'],
    'endothelial': ['Endothelial'],
    'vlmc': ['VLMC'],
    }

cell_supertype = list(chain(*list(subclass.values())))

# %% [markdown]
# ## **Load and Prep Data**
#
# load the preprocessed and annotated data.
#
# Make sure the anndata has the count data in either `.layers` or in `.X`. if count data is not in `.layers` it will be assumed that `.X ` contains the counts

# %%
# adata_annot = sc.read_h5ad(f'../data/raw/{save_prefix}/anndata/rna/{cell_group}_raw_anndata.h5ad')
adata_annot = sc.read_h5ad(os.path.join(data_dir, f'anndata/{save_prefix.upper()}_RNAseq_final-nuclei.2024-02-13.h5ad'))
adata_annot.obs_names_make_unique()
adata_annot.var_names_make_unique()

if 'counts' not in adata_annot.layers.keys():
    print('"counts" not in layers...')
    print('analysis requires unnormalized count data...')
    print('"adata.X" will be used as count data...')

# del adata_annot.obsm, adata_annot.varm, adata_annot.uns, adata_annot.obsp, adata_annot.var, adata_annot.layers

celltypes = list(adata_annot.obs[cell_type_column].unique())

# map the pathology group to the subject id in .obs

adata_annot = adata_annot[adata_annot.obs.Subclass.isin(cell_supertype)]
adata_annot = adata_annot[adata_annot.obs['Neurotypical reference'] == 'False']
adata_annot = adata_annot[adata_annot.obs['Severely Affected Donor'] == 'N']

adata_annot
# Out:
# "counts" not in layers...
# analysis requires unnormalized count data...
# "adata.X" will be used as count data...
# View of AnnData object with n_obs × n_vars = 1164766 × 36601
#     obs: 'sample_id', 'Neurotypical reference', 'Donor ID', 'Organism', 'Brain Region', 'Sex', 'Gender', 'Age at Death', 'Race (choice=White)', 'Race (choice=Black/ African American)', 'Race (choice=Asian)', 'Race (choice=American Indian/ Alaska Native)', 'Race (choice=Native Hawaiian or Pacific Islander)', 'Race (choice=Unknown or unreported)', 'Race (choice=Other)', 'specify other race', 'Hispanic/Latino', 'Highest level of education', 'Years of education', 'PMI', 'Fresh Brain Weight', 'Brain pH', 'Overall AD neuropathological Change', 'Thal', 'Braak', 'CERAD score', 'Overall CAA Score', 'Highest Lewy Body Disease', 'Total Microinfarcts (not observed grossly)', 'Total microinfarcts in screening sections', 'Atherosclerosis', 'Arteriolosclerosis', 'LATE', 'Cognitive Status', 'Last CASI Score', 'Interval from last CASI in months', 'Last MMSE Score', 'Interval from last MMSE in months', 'Last MOCA Score', 'Interval from last MOCA in months', 'APOE Genotype', 'Primary Study Name', 'Secondary Study Name', 'NeuN positive fraction on FANS', 'RIN', 'cell_prep_type', 'facs_population_plan', 'rna_amplification', 'sample_name', 'sample_quantity_count', 'expc_cell_capture', 'method', 'pcr_cycles', 'percent_cdna_longer_than_400bp', 'rna_amplification_pass_fail', 'amplified_quantity_ng', 'load_name', 'library_prep', 'library_input_ng', 'r1_index', 'avg_size_bp', 'quantification_fmol', 'library_prep_pass_fail', 'exp_component_vendor_name', 'batch_vendor_name', 'experiment_component_failed', 'alignment', 'Genome', 'ar_id', 'bc', 'GEX_Estimated_number_of_cells', 'GEX_number_of_reads', 'GEX_sequencing_saturation', 'GEX_Mean_raw_reads_per_cell', 'GEX_Q30_bases_in_barcode', 'GEX_Q30_bases_in_read_2', 'GEX_Q30_bases_in_UMI', 'GEX_Percent_duplicates', 'GEX_Q30_bases_in_sample_index_i1', 'GEX_Q30_bases_in_sample_index_i2', 'GEX_Reads_with_TSO', 'GEX_Sequenced_read_pairs', 'GEX_Valid_UMIs', 'GEX_Valid_barcodes', 'GEX_Reads_mapped_to_genome', 'GEX_Reads_mapped_confidently_to_genome', 'GEX_Reads_mapped_confidently_to_intergenic_regions', 'GEX_Reads_mapped_confidently_to_intronic_regions', 'GEX_Reads_mapped_confidently_to_exonic_regions', 'GEX_Reads_mapped_confidently_to_transcriptome', 'GEX_Reads_mapped_antisense_to_gene', 'GEX_Fraction_of_transcriptomic_reads_in_cells', 'GEX_Total_genes_detected', 'GEX_Median_UMI_counts_per_cell', 'GEX_Median_genes_per_cell', 'Multiome_Feature_linkages_detected', 'Multiome_Linked_genes', 'Multiome_Linked_peaks', 'ATAC_Confidently_mapped_read_pairs', 'ATAC_Fraction_of_genome_in_peaks', 'ATAC_Fraction_of_high_quality_fragments_in_cells', 'ATAC_Fraction_of_high_quality_fragments_overlapping_TSS', 'ATAC_Fraction_of_high_quality_fragments_overlapping_peaks', 'ATAC_Fraction_of_transposition_events_in_peaks_in_cells', 'ATAC_Mean_raw_read_pairs_per_cell', 'ATAC_Median_high_quality_fragments_per_cell', 'ATAC_Non-nuclear_read_pairs', 'ATAC_Number_of_peaks', 'ATAC_Percent_duplicates', 'ATAC_Q30_bases_in_barcode', 'ATAC_Q30_bases_in_read_1', 'ATAC_Q30_bases_in_read_2', 'ATAC_Q30_bases_in_sample_index_i1', 'ATAC_Sequenced_read_pairs', 'ATAC_TSS_enrichment_score', 'ATAC_Unmapped_read_pairs', 'ATAC_Valid_barcodes', 'Number of mapped reads', 'Number of unmapped reads', 'Number of multimapped reads', 'Number of reads', 'Number of UMIs', 'Genes detected', 'Doublet score', 'Fraction mitochondrial UMIs', 'Used in analysis', 'Class confidence', 'Class', 'Subclass confidence', 'Subclass', 'Supertype confidence', 'Supertype (non-expanded)', 'Supertype', 'Continuous Pseudo-progression Score', 'Severely Affected Donor'
#     var: 'gene_ids'
#     uns: 'APOE4 Status_colors', 'Braak_colors', 'CERAD score_colors', 'Cognitive Status_colors', 'Great Apes Metadata', 'Highest Lewy Body Disease_colors', 'LATE_colors', 'Overall AD neuropathological Change_colors', 'Sex_colors', 'Subclass_colors', 'Supertype_colors', 'Thal_colors', 'UW Clinical Metadata', 'X_normalization', 'batch_condition', 'default_embedding', 'neighbors', 'title', 'umap'
#     obsm: 'X_scVI', 'X_umap'
#     layers: 'UMIs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # **Parameters for Testing Differential Pathway Activity**
#
# The primary differential pathway activity analaysis:
#
# - `covariates`: Specifies variables to account for in the analysis:
#     - Must include `Continuous Pseudo-progression Score` which will later on be matched to`pathology.group` as the primary variable of interest.
#
#     - Can include additional confounding variables like:
#         - Demographic factors (e.g., `Sex`, `Age`)
#         - Technical factors (e.g., `Sample Batch`)
#
#     - If there are no additional confounders, set `covariates = ['Continuous Pseudo-progression Score']`.
#
#     - For the best results, ensure:
#         - continuous covariates are similarly scaled.
#         - uniformity in categorical data. E.g., Avoid having 'M', 'Male', and 'male' in the same dataset.
#         - regularly assess the impact of covariates by running the analyses with and without each covariate. Watch out for covariates unduly influencing results. Watch out for covariates unduly influencing results.
#
# - `random_effect`: Identifies the technical variable to be treated as random effects (in this case `subject_id` or `Sample_batch`). These effects are regressed out using `duplicatecorrection`. This would help account or technical variation not relevant to the biological question.

# %%
######################### Differential Pathway Activity arguments #########################
random_effect = helper_functions.clean_strings([subject_id])[0]     # Technical covariate to be included as random effect not of interest (regressed out by duplicatecorrection)
subject_id = random_effect

covariates = [
    'Continuous Pseudo-progression Score',
    'Age at Death binned codes',
    'Sex',
    'PMI',
    'Genes detected',
    'Number of UMIs',
    'method',
    'Race (choice=White)',
    'APOE4_Status'
]

covariates = helper_functions.clean_strings(covariates, replace_hyphen=True)

numeric_covariates = helper_functions.clean_strings(['Age at Death',
                                            'Continuous Pseudo-progression Score', 
                                            'PMI',
                                            'Genes detected',
                                            'Number of UMIs'], 
                                            replace_hyphen=True)

# %% [markdown]
# # **Standardize Covariate Column Names in `adata.obs` and split/save adata at cell sublcass level**
#
#
# Prior to differential pathway analysis, we implement the comprehensive covariate standardization and categorization employed **[here](https://github.com/AllenInstitute/SEA-AD_2024/blob/main/Single%20nucleus%20omics/04_Differential%20expression%20analysis/00_Split%20AnnData%20for%20nebula.ipynb)** to ensure robust statistical comparisons.
#
# Continuous variables were normalized to a [0,1] interval using min-max scaling, including `post-mortem interval (PMI)` and `the number of genes detected per cell`.
#
# `Age at death` was discretized into five equal-width bins and subsequently normalized to account for non-linear age effects.
#
# Categorical variables underwent systematic preprocessing to ensure consistent encoding. `Sex` was binary-encoded as F/M, while `APOE4` carrier status was derived from genotype information and encoded as Y/N. Race information, specifically White identification, was encoded as Checked/Unchecked. Technical covariates, including sequencing method and donor ID, were retained with cleaned category levels.
#
# For quality control metrics, we normalized the `number of unique molecular identifiers (UMIs)` and `genes detected per cell`,to enabling direct comparisons across samples.

# %%
# adata_annot.obs["continuous_pseudo_progression_score"] = adata_annot.obs["Continuous Pseudo-progression Score"].copy()


# adata_annot.obs["Age at Death"] = adata_annot.obs["Age at Death"].astype("object")
# adata_annot.obs["Age at Death"] = [np.float32(i) for i in adata_annot.obs["Age at Death"]]
# adata_annot.obs["Age_at_Death_binned"] = pd.cut(adata_annot.obs["Age at Death"], bins=5)
# adata_annot.obs["age_at_death_binned_codes"] = adata_annot.obs["Age_at_Death_binned"].cat.codes
# adata_annot.obs["age_at_death_binned_codes"] = adata_annot.obs["age_at_death_binned_codes"] /  adata_annot.obs["age_at_death_binned_codes"].max()

# adata_annot.obs["sex"] = adata_annot.obs["Sex"].astype("category")
# adata_annot.obs["sex"] = adata_annot.obs["sex"].cat.remove_unused_categories()
# adata_annot.obs["sex"] = adata_annot.obs["sex"].cat.reorder_categories(["Female", "Male"])

# adata_annot.obs["race_choice_white"] = adata_annot.obs["Race (choice=White)"].astype("category")
# adata_annot.obs["race_choice_white"] = adata_annot.obs["race_choice_white"].cat.remove_unused_categories()
# adata_annot.obs["race_choice_white"] = adata_annot.obs["race_choice_white"].cat.reorder_categories(["Unchecked", "Checked"])

# adata_annot.obs["method"] = adata_annot.obs["method"].cat.remove_unused_categories()

# adata_annot.obs["genes_detected"] = (adata_annot.obs["Genes detected"] - adata_annot.obs["Genes detected"].min()) /\
#                                      (adata_annot.obs["Genes detected"].max() - adata_annot.obs["Genes detected"].min())

# adata_annot.obs["donor_id"] = adata_annot.obs["Donor ID"].copy()

# adata_annot.obs["number_of_umis"] = adata_annot.obs["Number of UMIs"].copy()

# adata_annot.obs["PMI"] = adata_annot.obs["PMI"].astype(float)
# adata_annot.obs["pmi"] = (adata_annot.obs["PMI"] - adata_annot.obs["PMI"].min()) /  (adata_annot.obs["PMI"].max() - adata_annot.obs["PMI"].min())

# adata_annot.obs["apoe4_status"] = adata_annot.obs["APOE Genotype"].str.contains("4")
# adata_annot.obs["apoe4_status"] = adata_annot.obs["apoe4_status"].astype("category")
# adata_annot.obs["apoe4_status"] = adata_annot.obs["apoe4_status"].cat.reorder_categories([False, True])
# adata_annot.obs["apoe4_status"] = adata_annot.obs["apoe4_status"].cat.rename_categories(
#     {
#         False: "N",
#         True: "Y",
#     }
# )

# for col in adata_annot.obs.keys():
#     if col not in covariates and col != cell_type_column and col!=random_effect and col not in ['Supertype (non-expanded)', 'Supertype']:
#             try:
#                 del adata_annot.obs[col]
#             except KeyError:
#                 continue

# adata_annot.write_h5ad(os.path.join(data_dir, f'anndata/all_subclass_standardized_anndata.h5ad'), compression='gzip')

# # split and save by subclass

for group in subclass:
    for cell_type in subclass[group]:
        adata_annot2 = adata_annot[adata_annot.obs[cell_type_column].isin([cell_type])]

        save_path = os.path.join(data_dir, 
                                 group,
                                 helper_functions.clean_strings(cell_type, preserve_case=True))
        
        os.makedirs(save_path, exist_ok=True)
        
        adata_annot2.write_h5ad(save_path + f'/{helper_functions.clean_strings(cell_type, preserve_case=True)}_standardized_anndata.h5ad',
                                compression='gzip')

adata_annot
# Out:
# AnnData object with n_obs × n_vars = 1164766 × 36601
#     obs: 'method', 'Subclass', 'Supertype (non-expanded)', 'Supertype', 'continuous_pseudo_progression_score', 'age_at_death_binned_codes', 'sex', 'race_choice_white', 'genes_detected', 'donor_id', 'number_of_umis', 'pmi', 'apoe4_status'
#     var: 'gene_ids'
#     uns: 'APOE4 Status_colors', 'Braak_colors', 'CERAD score_colors', 'Cognitive Status_colors', 'Great Apes Metadata', 'Highest Lewy Body Disease_colors', 'LATE_colors', 'Overall AD neuropathological Change_colors', 'Sex_colors', 'Subclass_colors', 'Supertype_colors', 'Thal_colors', 'UW Clinical Metadata', 'X_normalization', 'batch_condition', 'default_embedding', 'neighbors', 'title', 'umap'
#     obsm: 'X_scVI', 'X_umap'
#     layers: 'UMIs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # **Get Additional Suplementary Info From AWS**

# %%
import os
import boto3
from botocore import UNSIGNED
from botocore.client import Config

def download_s3_folder(bucket_name, s3_folder, local_dir):
    """
    Download the contents of a folder directory from an S3 bucket using anonymous access
    """
    # Create an anonymous S3 client
    s3 = boto3.client(
        's3',
        aws_access_key_id='',
        aws_secret_access_key='',
        config=Config(signature_version=UNSIGNED)
    )
    
    os.makedirs(local_dir, exist_ok=True)
    
    paginator = s3.get_paginator('list_objects_v2')
    pages = paginator.paginate(Bucket=bucket_name, Prefix=s3_folder)
    
    for page in pages:
        if 'Contents' in page:
            for obj in page['Contents']:
                key = obj['Key']
                if key.endswith('/'):
                    continue
                    
                local_file_path = os.path.join(local_dir, os.path.relpath(key, s3_folder))
                os.makedirs(os.path.dirname(local_file_path), exist_ok=True)
                
                print(f"Downloading {key} to {local_file_path}")
                s3.download_file(bucket_name, key, local_file_path)

bucket = 'sea-ad-single-cell-profiling'
s3_folder = 'MTG/RNAseq/Supplementary Information/'
local_dir = '/media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/'

download_s3_folder(bucket, s3_folder, local_dir)
# Out:
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_6-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Astro_Astro_6-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Chandelier_Chandelier_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Chandelier_Chandelier_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Chandelier_Chandelier_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Chandelier_Chandelier_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Endo_Endo_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Endo_Endo_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Endo_Endo_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Endo_Endo_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Endo_Endo_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Endo_Endo_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_10_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_10_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_12_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_12_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_13_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_13_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_7_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_7_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_8_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L2 3 IT_L2 3 IT_8_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L4 IT_L4 IT_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 6 NP_L5 6 NP_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 ET_L5 ET_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 ET_L5 ET_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 ET_L5 ET_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 ET_L5 ET_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_7_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L5 IT_L5 IT_7_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 CT_L6 CT_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT Car3_L6 IT Car3_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT Car3_L6 IT Car3_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT Car3_L6 IT Car3_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT Car3_L6 IT Car3_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT Car3_L6 IT Car3_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT Car3_L6 IT Car3_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT_L6 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT_L6 IT_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT_L6 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6 IT_L6 IT_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/L6b_L6b_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lamp5_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lhx6_Lamp5_Lhx6_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Lamp5_Lhx6_Lamp5_Lhx6_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Lymphocyte_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Lymphocyte_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_2_1-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_2_1-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_2_3-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_2_3-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_3-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_3-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_4-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Micro-PVM_4-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Monocyte_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Micro-PVM_Monocyte_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_2_1-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_2_1-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_2_2-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_2_2-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/OPC_OPC_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_2_1-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_2_1-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Oligo_Oligo_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pax6_Pax6_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_10_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_10_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_12_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_12_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_13_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_13_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_14_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_14_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_15_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_15_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_7_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_7_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_8_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_8_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_9_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Pvalb_Pvalb_9_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_8_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sncg_Sncg_8_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst Chodl_Sst Chodl_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst Chodl_Sst Chodl_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst Chodl_Sst Chodl_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst Chodl_Sst Chodl_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_10_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_10_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_11_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_11_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_12_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_12_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_13_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_13_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_19_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_19_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_20_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_20_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_22_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_22_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_23_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_23_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_25_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_25_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_3_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_3_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_7_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_7_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_9_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Sst_Sst_9_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_Pericyte_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_Pericyte_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_Pericyte_2-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_Pericyte_2-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_SMC-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_SMC-SEAAD_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_VLMC_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/VLMC_VLMC_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_11_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_11_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_12_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_12_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_13_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_13_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_14_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_14_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_15_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_15_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_16_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_16_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_18_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_18_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_19_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_19_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_1_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_1_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_21_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/All Donors/Continuous_Pseudo-progression_Score/Vip_Vip_21_across_Continuous_Pseudo-progression_Score_DE.csv
# ...
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_2_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_2_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_4_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_4_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_5_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_5_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_6_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_6_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_9_across_Continuous_Pseudo-progression_Score_DE.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/Late Donors/Continuous_Pseudo-progression_Score/Vip_Vip_9_across_Continuous_Pseudo-progression_Score_DE.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/effect_size_table.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/effect_size_table.csv
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/effect_sizes.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/effect_sizes.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/effect_sizes_early.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/effect_sizes_early.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/effect_sizes_late.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/effect_sizes_late.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/effect_sizes_vs_all.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/effect_sizes_vs_all.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/fraction_expressed.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/fraction_expressed.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/gene_dynamic_space.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/gene_dynamic_space.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/mean_expression.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/mean_expression.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/pvalues.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/pvalues.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/pvalues_early.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/pvalues_early.h5ad
# Downloading MTG/RNAseq/Supplementary Information/Nebula Results/pvalues_late.h5ad to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Nebula Results/pvalues_late.h5ad
# Downloading MTG/RNAseq/Supplementary Information/SCENIC Results/eRegulon_metadata_filtered.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/SCENIC Results/eRegulon_metadata_filtered.csv
# Downloading MTG/RNAseq/Supplementary Information/SEAAD_MTG_ATACseq_all-nuclei_metadata.2024-12-06.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/SEAAD_MTG_ATACseq_all-nuclei_metadata.2024-12-06.csv
# Downloading MTG/RNAseq/Supplementary Information/SEAAD_MTG_RNAseq_all-nuclei_metadata.2024-02-13.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/SEAAD_MTG_RNAseq_all-nuclei_metadata.2024-02-13.csv
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 1.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 1.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 2.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 2.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 3.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 3.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 4.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 4.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 5.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 5.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 6.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 6.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 7.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 7.xlsx
# Downloading MTG/RNAseq/Supplementary Information/Supplementary Table 8.xlsx to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/Supplementary Table 8.xlsx
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Astrocyte/X_scVI.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Astrocyte/X_scVI.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Astrocyte/X_umap.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Astrocyte/X_umap.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Astrocyte/obs_names.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Astrocyte/obs_names.csv
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/L5 IT/.ipynb_checkpoints/obs_names-checkpoint.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/L5 IT/.ipynb_checkpoints/obs_names-checkpoint.csv
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/L5 IT/X_scVI.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/L5 IT/X_scVI.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/L5 IT/X_umap.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/L5 IT/X_umap.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/L5 IT/obs_names.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/L5 IT/obs_names.csv
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Microglia-PVM/X_scVI.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Microglia-PVM/X_scVI.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Microglia-PVM/X_umap.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Microglia-PVM/X_umap.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Microglia-PVM/obs_names.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Microglia-PVM/obs_names.csv
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Sst_Pvalb/X_scVI.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Sst_Pvalb/X_scVI.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Sst_Pvalb/X_umap.npy to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Sst_Pvalb/X_umap.npy
# Downloading MTG/RNAseq/Supplementary Information/UMAP Coordinates/Sst_Pvalb/obs_names.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/UMAP Coordinates/Sst_Pvalb/obs_names.csv
# Downloading MTG/RNAseq/Supplementary Information/cluster_order_and_colors.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/cluster_order_and_colors.csv
# Downloading MTG/RNAseq/Supplementary Information/dbs/AD_GWAS.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/AD_GWAS.csv
# Downloading MTG/RNAseq/Supplementary Information/dbs/AnimalTFDB.tsv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/AnimalTFDB.tsv
# Downloading MTG/RNAseq/Supplementary Information/dbs/Categorized_human_E3_ligases.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/Categorized_human_E3_ligases.csv
# Downloading MTG/RNAseq/Supplementary Information/dbs/GtP_receptors.tsv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/GtP_receptors.tsv
# Downloading MTG/RNAseq/Supplementary Information/dbs/KinHub_database.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/KinHub_database.csv
# Downloading MTG/RNAseq/Supplementary Information/dbs/uniprotkb_keyword_KW_0276_AND_reviewed_2024_02_06.tsv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/uniprotkb_keyword_KW_0276_AND_reviewed_2024_02_06.tsv
# Downloading MTG/RNAseq/Supplementary Information/dbs/uniprotkb_keyword_KW_0746_AND_reviewed_2024_02_06.tsv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/uniprotkb_keyword_KW_0746_AND_reviewed_2024_02_06.tsv
# Downloading MTG/RNAseq/Supplementary Information/dbs/uniprotkb_keyword_KW_0753_AND_reviewed_2024_02_06.tsv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/uniprotkb_keyword_KW_0753_AND_reviewed_2024_02_06.tsv
# Downloading MTG/RNAseq/Supplementary Information/dbs/uniprotkb_keyword_KW_1208_AND_reviewed_2024_02_06.tsv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/dbs/uniprotkb_keyword_KW_1208_AND_reviewed_2024_02_06.tsv
# Downloading MTG/RNAseq/Supplementary Information/scCODA Results/A9_RNAseq/Continuous_Pseudo-progression_Score/.ipynb_checkpoints/exc inh_supertype_scANVI_leiden_results-checkpoint.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/scCODA Results/A9_RNAseq/Continuous_Pseudo-progression_Score/.ipynb_checkpoints/exc inh_supertype_scANVI_leiden_results-checkpoint.csv
# Downloading MTG/RNAseq/Supplementary Information/scCODA Results/A9_RNAseq/Continuous_Pseudo-progression_Score/Neuronal: Glutamatergic Neuronal: GABAergic_Supertype_results.csv to /media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/scCODA Results/A9_RNAseq/Continuous_Pseudo-progression_Score/Neuronal: Glutamatergic Neuronal: GABAergic_Supertype_results.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 48
#      45 s3_folder = 'MTG/RNAseq/Supplementary Information/'
#      46 local_dir = '/media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/'
# ---> 48 download_s3_folder(bucket, s3_folder, local_dir)
#      50 download_s3_folder(bucket, s3_folder, local_dir)
#
# Cell In[12], line 41, in download_s3_folder(bucket_name, s3_folder, local_dir)
#      39 print(f"Downloading {key} to {local_file_path}")
#      40 # Download the file
# ---> 41 s3.download_file(bucket_name, key, local_file_path)
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/boto3/s3/inject.py:192, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     157 """Download an S3 object to a file.
#     158
#     159 Usage::
#    (...)
#     189     transfer.
#     190 """
#     191 with S3Transfer(self, Config) as transfer:
# --> 192     return transfer.download_file(
#     193         bucket=Bucket,
#     194         key=Key,
#     195         filename=Filename,
#     196         extra_args=ExtraArgs,
#     197         callback=Callback,
#     198     )
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/boto3/s3/transfer.py:406, in S3Transfer.download_file(self, bucket, key, filename, extra_args, callback)
#     402 future = self._manager.download(
#     403     bucket, key, filename, extra_args, subscribers
#     404 )
#     405 try:
# --> 406     future.result()
#     407 # This is for backwards compatibility where when retries are
#     408 # exceeded we need to throw the same error from boto3 instead of
#     409 # s3transfer's built in RetriesExceededError as current users are
#     410 # catching the boto3 one instead of the s3transfer exception to do
#     411 # their own retries.
#     412 except S3TransferRetriesExceededError as e:
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/futures.py:264, in TransferCoordinator.result(self)
#     261 # Once done waiting, raise an exception if present or return the
#     262 # final result.
#     263 if self._exception:
# --> 264     raise self._exception
#     265 return self._result
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/tasks.py:135, in Task.__call__(self)
#     131     # If the task is not done (really only if some other related
#     132     # task to the TransferFuture had failed) then execute the task's
#     133     # main() method.
#     134     if not self._transfer_coordinator.done():
# --> 135         return self._execute_main(kwargs)
#     136 except Exception as e:
#     137     self._log_and_set_exception(e)
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/tasks.py:158, in Task._execute_main(self, kwargs)
#     155 # Log what is about to be executed.
#     156 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 158 return_value = self._main(**kwargs)
#     159 # If the task is the final task, then set the TransferFuture's
#     160 # value to the return value from main().
#     161 if self._is_final:
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/download.py:640, in IOWriteTask._main(self, fileobj, data, offset)
#     633 def _main(self, fileobj, data, offset):
#     634     """Pulls off an io queue to write contents to a file
#     635
#     636     :param fileobj: The file handle to write content to
#     637     :param data: The data to write
#     638     :param offset: The offset to write the data to.
#     639     """
# --> 640     fileobj.seek(offset)
#     641     fileobj.write(data)
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/utils.py:385, in DeferredOpenFile.seek(self, where, whence)
#     384 def seek(self, where, whence=0):
# --> 385     self._open_if_needed()
#     386     self._fileobj.seek(where, whence)
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/utils.py:368, in DeferredOpenFile._open_if_needed(self)
#     366 def _open_if_needed(self):
#     367     if self._fileobj is None:
# --> 368         self._fileobj = self._open_function(self._filename, self._mode)
#     369         if self._start_byte != 0:
#     370             self._fileobj.seek(self._start_byte)
#
# File ~/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/s3transfer/utils.py:279, in OSUtils.open(self, filename, mode)
#     278 def open(self, filename, mode):
# --> 279     return open(filename, mode)
#
# OSError: [Errno 22] Invalid argument: '/media/tadeoye/Volume1/data/seq/SEA-AD/supplementary/scCODA Results/A9_RNAseq/Continuous_Pseudo-progression_Score/Neuronal: Glutamatergic Neuronal: GABAergic_Supertype_results.csv.ddEAe8cc'

# %%
# Out:
# <?xml version="1.0" encoding="utf-8"?>
