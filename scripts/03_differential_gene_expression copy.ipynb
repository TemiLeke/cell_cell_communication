# %%
import warnings
from warnings import simplefilter
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=PendingDeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning, module='anndata')
warnings.filterwarnings('ignore', message='.*reticulate.*')

# %%
import os
import rpy2
import logging
import warnings
import anndata2ri
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
from itertools import chain
from datetime import datetime
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from scipy.sparse import csr_matrix
from joblib import Parallel, delayed
from functions import helper_functions
from matplotlib.pyplot import rcParams
from functions.run_nebula import run_de_tests, build_effect_size_anndata, get_standardized_effects

# %%
# # Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# Automatically convert rpy2 outputs to pandas dataframes
pandas2ri.activate()
anndata2ri.activate()
# %load_ext rpy2.ipython

sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()

simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
# Out:
# -----
# anndata     0.11.1
# scanpy      1.9.3
# -----
# PIL                         9.5.0
# anndata2ri                  1.1
# asttokens                   NA
# backcall                    0.2.0
# cffi                        1.15.1
# comm                        0.1.3
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# decoupler                   1.4.0
# dot_parser                  NA
# exceptiongroup              1.1.1
# executing                   1.2.0
# functions                   NA
# google                      NA
# gsva_prep                   NA
# h5py                        3.9.0
# igraph                      0.10.4
# ipykernel                   6.23.2
# ipywidgets                  8.0.6
# jedi                        0.18.2
# jinja2                      3.1.2
# joblib                      1.2.0
# kiwisolver                  1.4.4
# leidenalg                   0.9.1
# llvmlite                    0.39.1
# louvain                     0.8.0
# markupsafe                  2.1.3
# matplotlib                  3.7.1
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# numba                       0.56.4
# numexpr                     2.8.4
# numpy                       1.23.5
# nvfuser                     NA
# opt_einsum                  v3.3.0
# packaging                   23.1
# pandas                      2.0.2
# parso                       0.8.3
# patsy                       0.5.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.7.0
# plotly                      5.24.1
# prompt_toolkit              3.0.38
# psutil                      5.9.5
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     12.0.1
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pydot                       1.4.2
# pygments                    2.15.1
# pyparsing                   3.1.0
# pytz                        2023.3
# pytz_deprecation_shim       NA
# rpy2                        3.5.12
# scipy                       1.10.1
# seaborn                     0.12.2
# session_info                1.0.0
# setuptools                  68.0.0
# six                         1.16.0
# sklearn                     1.2.2
# sparse                      0.14.0
# stack_data                  0.6.2
# statsmodels                 0.14.0
# sympy                       1.12
# texttable                   1.6.7
# threadpoolctl               3.1.0
# torch                       2.0.1+cu117
# tornado                     6.3.2
# tqdm                        4.65.0
# traitlets                   5.9.0
# typing_extensions           NA
# tzlocal                     NA
# vscode                      NA
# wcwidth                     0.2.6
# yaml                        6.0
# zmq                         25.1.0
# zoneinfo                    NA
# -----
# IPython             8.14.0
# jupyter_client      8.2.0
# jupyter_core        5.3.1
# -----
# Python 3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]
# Linux-6.8.0-52-generic-x86_64-with-glibc2.35
# -----
# Session information updated at 2025-04-02 17:59

# %%
# %%R
#
# suppressPackageStartupMessages({
#     library(Matrix)
#     library(viridis)
#     library(harmony)
#     library(ggpubr)
#     library(tictoc)
#     library(RColorBrewer)
#     library(Hmisc)
#     library(corrplot)
#     library(grid)
#     library(gridExtra)
#     library(igraph)
#     library(ggrepel)
#     library(readxl)
#     library(conflicted)
#     library(dplyr)
#     library(parallel)
#     library(stringr)
#     library(tibble)
#     library(BiocParallel)
#
#     # single-cell analysis package
#     library(Seurat)
#     library(zellkonverter)
#     library(SingleCellExperiment)
#     library(tidyr)
#     library(readxl)
#     library(GSA)
#     library(limma)
#
#     # plotting and data science packages
#     library(tidyverse)
#     library(cowplot)
#     library(patchwork)
#     library(ggplot2)
#
#     # co-expression network analysis packages:
#     library(WGCNA)
#     library(hdWGCNA)
#
#     # gene enrichment packages
#     library(enrichR)
#     library(GeneOverlap)
#     library(GSEABase)
#     library(GSVA)
#
#     # cell-cell communication
#     library(nichenetr)
#
# # needs to be run every time you start R and want to use %>%
# })
#
# # using the cowplot theme for ggplot
# theme_set(theme_cowplot())
#
# # set random seed for reproducibility
# set.seed(12345)
#
# # optionally enable multithreading
# enableWGCNAThreads(nThreads = 40)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#     Allowing parallel execution with up to 40 working processes.
# In addition: Warning messages:
# 1: replacing previous import ‘GenomicRanges::intersect’ by ‘SeuratObject::intersect’ when loading ‘hdWGCNA’
# 2: replacing previous import ‘GenomicRanges::union’ by ‘dplyr::union’ when loading ‘hdWGCNA’
# 3: replacing previous import ‘GenomicRanges::setdiff’ by ‘dplyr::setdiff’ when loading ‘hdWGCNA’
# 4: replacing previous import ‘dplyr::as_data_frame’ by ‘igraph::as_data_frame’ when loading ‘hdWGCNA’
# 5: replacing previous import ‘Seurat::components’ by ‘igraph::components’ when loading ‘hdWGCNA’
# 6: replacing previous import ‘dplyr::groups’ by ‘igraph::groups’ when loading ‘hdWGCNA’
# 7: replacing previous import ‘dplyr::union’ by ‘igraph::union’ when loading ‘hdWGCNA’
# 8: replacing previous import ‘GenomicRanges::subtract’ by ‘magrittr::subtract’ when loading ‘hdWGCNA’
# 9: replacing previous import ‘Matrix::as.matrix’ by ‘proxy::as.matrix’ when loading ‘hdWGCNA’
# 10: replacing previous import ‘igraph::groups’ by ‘tidygraph::groups’ when loading ‘hdWGCNA’

# %% [markdown]
# ## **Data Prep Parameters**
#
# - `test_names`: List of the different test names of interest.
#
# - `save_prefix`: Preferred prefix for saving critical files. Ideally chosen to be in the format `{source name}_{brain region}`. e.g `mathys_pfc`
#
# - `subject_id`: Column name for Subject/Patient ID in both metadata and `.obs`

# %%
save_prefix = 'seaad_mtg'                                       # this takes the format '{StudyName}_{ThreeLetterAccronymForBrainRegion}'
subject_id = helper_functions.clean_strings('Donor ID')
cell_type_column = 'Subclass'                       # 'Supertype (non-expanded)', 'Subclass'
pseudobulk_level = 'Supertype'                      # Level at which cells are aggregated into pseudobulks,
factor = 'Continuous Pseudo-progression Score'    # pathology.group # Continuous Pseudoprogression Score
factor = helper_functions.clean_strings(factor, replace_hyphen=True)
test_names = ['late_vs_early']                                  # test categories
region_name = save_prefix.split('_')[-1].upper()
count_agg_strategy = 'metacell'   # options 'network', 'random', 'pseudobulk', 'smaller_network', 'standardbulk', 'metacell', `blanchardbulk``


data_dir = f'/media/tadeoye/Volume1/data/seq/SEA-AD/{region_name}/RNAseq/'
save_dir = f'../results/'

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

subclass = {
    'excitatory': ['L5 IT', 'L2/3 IT', 'L4 IT', 'L6 IT', 'L6 IT Car3', 'L5/6 NP', 'L6b', 'L6 CT', 'L5 ET'],
    'inhibitory': ['Pvalb', 'Sst', 'Lamp5 Lhx6', 'Vip', 'Lamp5', 'Sncg', 'Chandelier', 'Sst Chodl', 'Pax6'],
    'astrocyte': ['Astrocyte'],
    'microglia': ['Microglia-PVM'],
    'opc': ['OPC'],
    'oligodendrocyte': ['Oligodendrocyte'],
    'endothelial': ['Endothelial'],
    'vlmc': ['VLMC'],
    }

cell_supertypes = list(chain(*list(subclass.values())))

# %% [markdown]
# # **Load Merged Pseudo-bulked Data**
#
# We have merged the pseduobulked data for all cell sypertypes (`02_merge_pseudobulks.ipynb`). Now, we load the merged data.

# %%
clean_subclass = robjects.ListVector({k: [helper_functions.clean_strings(v, preserve_case=True) for v in val] for k, val in subclass.items()})
clean_cell_supertypes = [helper_functions.clean_strings(cell_type, preserve_case=True) for cell_type in cell_supertypes]

# %%
adata_merged = sc.read_h5ad(data_dir+f'counts/anndata/all_subclass_{count_agg_strategy}_anndata.h5ad')
adata_merged.X = csr_matrix(adata_merged.X)

adata_annot = sc.read_h5ad(os.path.join(data_dir, f'counts/anndata/{save_prefix.upper()}_RNAseq_final-nuclei.2024-02-13.h5ad'))
adata_annot.X = adata_annot.layers['UMIs'] 

Subclass = robjects.ListVector(subclass)

# %%
# %%R -i adata_merged -i count_agg_strategy -i data_dir -i subject_id -i Subclass -i cell_supertypes -i clean_cell_supertypes -i clean_subclass
#
# source('../scripts/functions/helper_functions.r')
#
# print('Merged data loaded')
# adata_merged
# Out:
# [1] "Merged data loaded"
# class: SingleCellExperiment
# dim: 36601 111258
# metadata(0):
# assays(2): X logcounts
# rownames(36601): MIR1302-2HG FAM138A ... AC007325.4 AC007325.2
# rowData names(0):
# colnames(111258): L5 IT_1#H19.33.004_1 L5 IT_1#H19.33.004_2 ...
#   VLMC_1#H21.33.027_5 VLMC_1#H21.33.027_6
# colData names(21): donor_id orig.ident ... pseudo_genes_detected
#   pseudo_number_of_umis
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):

# %%
# del adata_merged, summed_counts_per_celltype

# %%
n_cores = 40

covariates = [
    'Continuous Pseudo-progression Score',
    'Age at Death binned codes',
    'Sex',
    'APOE4_Status',
    'Pseudo Genes Detected',
    'Pseudo Number of UMIs',
    # 'PMI',
    'method',
    'Race (choice=White)',
]

covariates = helper_functions.clean_strings(covariates, replace_hyphen=True)

# %%
if run_differential_expression:
    # Set up parameters
    params = {
        'region': 'MTG',
        'target': '',
        'split_key': pseudobulk_level,
        'outgroup_de': False, 
        'outgroup': '', 
        'covariates': covariates,
        'random_effect': subject_id,
        'covariate_formula': ' + '.join(covariates[1:]) + " + ",
        'tests': [factor],
        'layer': 'X',  
        'offset_variable': helper_functions.clean_strings('Pseudo Number of UMIs'),
        'group_cell': False,
        'save_dir': data_dir+'results/differential_gene_expression'  
    }

    adata_merged.obs[params['split_key']] = adata_merged.obs[params['split_key']].astype('category')

    os.makedirs(params['save_dir'], exist_ok=True)

    def process_target(target, adata_merged, params, cell_type_column):
        adata = adata_merged[adata_merged.obs[cell_type_column] == target]
        results = []
        for b in adata.obs[params['split_key']].cat.categories:
            try:
                result = run_de_tests(
                    adata_merged,
                    params['region'],
                    helper_functions.clean_strings(target,preserve_case=True,replace_hyphen=False),
                    params['split_key'],
                    params['outgroup_de'],
                    b,
                    params['covariates'],
                    params['random_effect'],
                    params['covariate_formula'],
                    params['tests'],
                    params['layer'],
                    params['offset_variable'],
                    params['group_cell'],
                    params['save_dir']
                )
                results.append(result)
            except Exception as e:
                error_msg = str(e)
                if "Some predictors have zero variation or a zero vector" in error_msg:
                    print(f"{datetime.now()} -- Skipping {b} because some predictors have zero variation or a zero vector")
                else:
                    print(f"{datetime.now()} -- Error processing {b}: {str(e)}") 
                continue
                
        return results

    # Parallelize at target level
    targets = adata_merged.obs[cell_type_column].unique()
    results = Parallel(n_jobs=n_cores)(
        delayed(process_target)(target, adata_merged, params, cell_type_column) 
        for target in targets
    )
# Out:
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:48.718252 -- No outgroup specified, running analysis for all groups and tests
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
#
# /home/tadeoye/miniconda3/envs/scRNA_seq_meta_analysis/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# 2025-01-21 13:27:50.040343 -- No outgroup specified, running analysis for all groups and tests
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#     2025-01-21 13:27:50.713590 -- Removing 3697 features from L5_IT_1 for low numbers of counts per cell
# 2025-01-21 13:27:50.848823 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:50.850709 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:50.909977 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 1476 genes in L5_IT_1 because all values are 0 for that covariate
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:51.736980 -- No outgroup specified, running analysis for all groups and tests
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#     2025-01-21 13:27:52.565351 -- Removing 4218 features from L4_IT_1 for low numbers of counts per cell
# 2025-01-21 13:27:52.706466 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:52.707825 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:52.759539 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 885 genes in L4_IT_1 because all values are 0 for that covariate
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:53.079388 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-21 13:27:53.134722 -- Removing 7505 features from L6_IT_Car3_1 for low numbers of counts per cell
# 2025-01-21 13:27:53.143022 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:53.159398 -- Adding 3 pseudocounts to continuous_pseudo_progression_score=0.0 for 4357 genes in L6_IT_Car3_1 because all values are 0 for that covariate
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#     2025-01-21 13:27:54.342556 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-21 13:27:54.438180 -- No outgroup specified, running analysis for all groups and tests
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
#
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:54.707096 -- Removing 4471 features from L5_6_NP_1 for low numbers of counts per cell
# 2025-01-21 13:27:54.739760 -- Removing 4169 features from L6_IT_1 for low numbers of counts per cell
# 2025-01-21 13:27:54.766883 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:54.768220 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:54.798369 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:54.800265 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:54.799585 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 2053 genes in L5_6_NP_1 because all values are 0 for that covariate
# 2025-01-21 13:27:54.834197 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 1528 genes in L6_IT_1 because all values are 0 for that covariate
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:56.936526 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-21 13:27:57.198544 -- Removing 5968 features from Pvalb_1 for low numbers of counts per cell
# 2025-01-21 13:27:57.243447 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:57.292248 -- Adding 3 pseudocounts to continuous_pseudo_progression_score=0.8095932638239676 for 2905 genes in Pvalb_1 because all values are 0 for that covariate
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:57.775866 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-21 13:27:57.900479 -- Removing 4622 features from L6_CT_1 for low numbers of counts per cell
# 2025-01-21 13:27:57.915561 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:57.916952 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:57.935106 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 2299 genes in L6_CT_1 because all values are 0 for that covariate
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:58.238245 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-21 13:27:58.279042 -- Removing 11698 features from L6b_2 for low numbers of counts per cell
# 2025-01-21 13:27:58.282031 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:58.282619 -- Removing continuous_pseudo_progression_score from the covariate formula
# 2025-01-21 13:27:58.283791 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:58.284199 -- Removing age_at_death_binned_codes from the covariate formula
# 2025-01-21 13:27:58.284741 -- Removing sex from the covariate formula
# 2025-01-21 13:27:58.285022 -- Removing apoe4_status from the covariate formula
# 2025-01-21 13:27:58.286112 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:58.299699 -- Adding 3 pseudocounts to pseudo_genes_detected=0.0 for 5399 genes in L6b_2 because all values are 0 for that covariate
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# R[write to console]: here() starts at /home/tadeoye/Documents/research_codes/cell_cell_communication
# 2025-01-21 13:27:59.504843 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-21 13:27:59.533555 -- Removing 16021 features from Sst_2 for low numbers of counts per cell
# 2025-01-21 13:27:59.536573 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:59.536959 -- Removing continuous_pseudo_progression_score from the covariate formula
# 2025-01-21 13:27:59.537990 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:59.538230 -- Removing age_at_death_binned_codes from the covariate formula
# 2025-01-21 13:27:59.538592 -- Removing sex from the covariate formula
# 2025-01-21 13:27:59.538835 -- Removing apoe4_status from the covariate formula
# 2025-01-21 13:27:59.539876 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-21 13:27:59.553788 -- Adding 3 pseudocounts to pseudo_genes_detected=0.2540227806906527 for 3420 genes in Sst_2 because all values are 0 for that covariate
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# ...
# 2025-01-22 03:48:36.317889 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 03:48:36.319042 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 03:48:36.319464 -- Removing method from the covariate formula
# 2025-01-22 03:48:36.319576 -- Removing race_choice_white from the covariate formula
# 2025-01-22 03:48:38.811403 -- Starting Pvalb_12 across continuous_pseudo_progression_score
# The cells are already grouped.Remove  0  genes having low expression.
# Analyzing  31225  genes with  4  subjects and  767  cells.
# 2025-01-22 03:51:01.718570 -- Pvalb_12 along continuous_pseudo_progression_score was written to disk
# 2025-01-22 03:51:03.037997 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 03:51:03.360062 -- Removing 5485 features from Pvalb_14 for low numbers of counts per cell
# 2025-01-22 03:51:03.403819 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 03:51:03.432492 -- Adding 3 pseudocounts to continuous_pseudo_progression_score=0.5750832273486403 for 2736 genes in Pvalb_14 because all values are 0 for that covariate
# 2025-01-22 04:04:37.687388 -- Adding 3 pseudocounts to continuous_pseudo_progression_score=0.6980818916251965 for 3367 genes in Pvalb_14 because all values are 0 for that covariate
# 2025-01-22 04:21:20.593411 -- Adding 3 pseudocounts to continuous_pseudo_progression_score=0.0 for 1102 genes in Pvalb_14 because all values are 0 for that covariate
# 2025-01-22 04:26:50.901645 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 04:26:51.176321 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 04:26:51.177413 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 04:26:51.178017 -- Removing method from the covariate formula
# 2025-01-22 04:26:51.178284 -- Removing race_choice_white from the covariate formula
# 2025-01-22 04:26:51.940693 -- Starting Pvalb_14 across continuous_pseudo_progression_score
# The cells are already grouped.Remove  5  genes having low expression.
# Analyzing  31111  genes with  3  subjects and  357  cells.
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In nebula(counts, obs$donor_id, pred = df, offset = obs$pseudo_number_of_umis,  :
# R[write to console]:
#
# R[write to console]:  Some predictors in the design matrix are collinear or linearly dependent. The effects of these predictors are not identifiable.
# 2025-01-22 04:28:47.188093 -- Pvalb_14 along continuous_pseudo_progression_score was written to disk
# 2025-01-22 04:28:48.020374 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 04:28:50.500477 -- Removing 4636 features from Pvalb_15 for low numbers of counts per cell
# 2025-01-22 04:28:50.981817 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 04:28:50.983095 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 04:28:51.334298 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.75 for 75 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 04:32:19.825550 -- Adding 3 pseudocounts to age_at_death_binned_codes=1.0 for 330 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 04:47:43.233803 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 734 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 04:49:57.172146 -- Skipping L2_3_IT_6 along continuous_pseudo_progression_score (already exists)
# 2025-01-22 04:49:58.102094 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 04:49:58.269378 -- Removing 4185 features from L2_3_IT_7 for low numbers of counts per cell
# 2025-01-22 04:49:58.291342 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 04:49:58.292568 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 04:49:58.317673 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 3764 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 04:59:44.874296 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.5 for 2827 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:07:09.243170 -- Adding 3 pseudocounts to age_at_death_binned_codes=1.0 for 3732 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:16:56.549744 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.75 for 1411 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:20:38.223548 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.0 for 5064 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:21:51.179938 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.0 for 1529 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 05:34:06.851800 -- Adding 3 pseudocounts to sex=Female for 7 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:34:07.996314 -- Adding 3 pseudocounts to sex=Male for 3 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:34:08.603595 -- Adding 3 pseudocounts to apoe4_status=Y for 12 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:34:10.572983 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 05:34:10.574052 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 05:34:10.624194 -- Adding 3 pseudocounts to method=10xMulti for 2732 genes in L2_3_IT_7 because all values are 0 for that covariate
# 2025-01-22 05:41:24.627849 -- Removing race_choice_white from the covariate formula
# 2025-01-22 05:41:24.937769 -- Skipping L2_3_IT_7 along continuous_pseudo_progression_score (already exists)
# 2025-01-22 05:41:25.821244 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 05:41:26.053885 -- Removing 4502 features from L2_3_IT_8 for low numbers of counts per cell
# 2025-01-22 05:41:26.099598 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 05:41:26.100719 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 05:41:26.123242 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 2478 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 05:52:19.663901 -- Adding 3 pseudocounts to age_at_death_binned_codes=1.0 for 1280 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 05:57:56.122754 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.5 for 1417 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 06:04:08.811717 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.75 for 899 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 06:08:07.313043 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.0 for 6092 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 06:32:46.795371 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.5 for 901 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 06:34:37.435909 -- Adding 3 pseudocounts to sex=Female for 37 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 06:34:47.331294 -- Adding 3 pseudocounts to apoe4_status=Y for 255 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 06:35:54.623763 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 06:35:54.624830 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 06:35:54.706023 -- Adding 3 pseudocounts to method=10xMulti for 5258 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 06:58:53.534912 -- Adding 3 pseudocounts to race_choice_white=Unchecked for 6709 genes in L2_3_IT_8 because all values are 0 for that covariate
# 2025-01-22 07:14:40.579326 -- Adding 3 pseudocounts to sex=Male for 8 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 07:15:03.260637 -- Adding 3 pseudocounts to apoe4_status=Y for 27 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 07:16:20.316419 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 07:16:20.317908 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 07:16:20.338065 -- Adding 3 pseudocounts to method=10xMulti for 5527 genes in Pvalb_15 because all values are 0 for that covariate
# 2025-01-22 07:28:10.085702 -- Skipping L2_3_IT_8 along continuous_pseudo_progression_score (already exists)
# 2025-01-22 07:28:11.002091 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 07:28:12.415044 -- Removing 3977 features from L2_3_IT_10 for low numbers of counts per cell
# 2025-01-22 07:28:12.723360 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 07:28:12.724989 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 07:28:12.774698 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 978 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 07:55:02.784252 -- Adding 3 pseudocounts to age_at_death_binned_codes=1.0 for 110 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 07:58:04.657210 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.5 for 66 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 07:59:53.743984 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.75 for 42 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 08:01:03.109658 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.0 for 1742 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 08:48:52.449511 -- Adding 3 pseudocounts to sex=Female for 2 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 08:48:56.609472 -- Adding 3 pseudocounts to apoe4_status=Y for 65 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 08:50:44.093828 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 08:50:44.095138 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 08:50:44.572408 -- Adding 3 pseudocounts to method=10xMulti for 2116 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 09:48:44.013112 -- Adding 3 pseudocounts to race_choice_white=Unchecked for 3799 genes in L2_3_IT_10 because all values are 0 for that covariate
# 2025-01-22 11:32:33.579970 -- Skipping L2_3_IT_10 along continuous_pseudo_progression_score (already exists)
# 2025-01-22 11:32:34.502683 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 11:32:34.943989 -- Removing 4080 features from L2_3_IT_12 for low numbers of counts per cell
# 2025-01-22 11:32:35.024733 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 11:32:35.026160 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 11:32:35.050617 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 1525 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 11:33:22.694103 -- Removing race_choice_white from the covariate formula
# 2025-01-22 11:33:32.430021 -- Starting Pvalb_15 across continuous_pseudo_progression_score
# The cells are already grouped.Remove  0  genes having low expression.
# Analyzing  31965  genes with  27  subjects and  3259  cells.
# 2025-01-22 11:37:48.172356 -- Pvalb_15 along continuous_pseudo_progression_score was written to disk
# 2025-01-22 11:44:50.524580 -- Adding 3 pseudocounts to age_at_death_binned_codes=1.0 for 946 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 11:52:20.350998 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.5 for 1101 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 12:01:04.785947 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.75 for 201 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 12:02:40.139762 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.0 for 4620 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 12:06:28.945331 -- Skipping Oligo_4 along continuous_pseudo_progression_score (already exists)
# 2025-01-22 12:38:44.984335 -- Adding 3 pseudocounts to sex=Female for 4 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 12:38:47.063209 -- Adding 3 pseudocounts to apoe4_status=Y for 70 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 12:39:19.945660 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 12:39:19.946928 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 12:39:20.078496 -- Adding 3 pseudocounts to method=10xMulti for 2628 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 12:59:55.605558 -- Adding 3 pseudocounts to race_choice_white=Unchecked for 8083 genes in L2_3_IT_12 because all values are 0 for that covariate
# 2025-01-22 14:03:10.570568 -- Skipping L2_3_IT_12 along continuous_pseudo_progression_score (already exists)
# 2025-01-22 14:03:12.657128 -- No outgroup specified, running analysis for all groups and tests
# 2025-01-22 14:03:14.614152 -- Removing 4118 features from L2_3_IT_13 for low numbers of counts per cell
# 2025-01-22 14:03:15.015424 -- Detected continuous_pseudo_progression_score as an integer or float, applying a min-max normalization
# 2025-01-22 14:03:15.016751 -- Detected age_at_death_binned_codes as an integer or float, applying a min-max normalization
# 2025-01-22 14:03:15.108949 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.25 for 265 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 14:13:04.403709 -- Adding 3 pseudocounts to age_at_death_binned_codes=1.0 for 100 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 14:16:43.813047 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.5 for 52 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 14:18:37.836929 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.75 for 8 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 14:18:55.640170 -- Adding 3 pseudocounts to age_at_death_binned_codes=0.0 for 1476 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 15:13:10.138993 -- Adding 3 pseudocounts to apoe4_status=Y for 7 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 15:13:25.619573 -- Detected pseudo_genes_detected as an integer or float, applying a min-max normalization
# 2025-01-22 15:13:25.621297 -- Detected pseudo_number_of_umis as an integer or float, applying a min-max normalization
# 2025-01-22 15:13:26.225798 -- Adding 3 pseudocounts to method=10xMulti for 1133 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 15:55:03.813523 -- Adding 3 pseudocounts to race_choice_white=Unchecked for 2328 genes in L2_3_IT_13 because all values are 0 for that covariate
# 2025-01-22 17:20:27.664842 -- Skipping L2_3_IT_13 along continuous_pseudo_progression_score (already exists)

# %%
blacklisted_genes = ["MTRNR2L12", "TTTY14", "USP9Y", "NLGN4Y", "UTY", "DDX3Y", "KDM5D", "TTTY10"]
blacklisted_genes.extend(adata_merged.var_names[adata_merged.var_names.str.startswith("MT-")].to_list())


effect_sizes, pvalues, std_errors  = build_effect_size_anndata(
    results_dir=os.path.join(data_dir+'results/differential_gene_expression',),
    glob_pattern="*.csv",
    file_pattern="_across_continuous_pseudo_progression_score_DE.csv",
    test="continuous_pseudo_progression_score",
    adata=adata_merged,
    subclass=cell_type_column,
    celltype=cell_type_column,
    blacklisted_genes=blacklisted_genes,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[173], line 5
#       1 blacklisted_genes = ["MTRNR2L12", "TTTY14", "USP9Y", "NLGN4Y", "UTY", "DDX3Y", "KDM5D", "TTTY10"]
#       2 blacklisted_genes.extend(adata_merged.var_names[adata_merged.var_names.str.startswith("MT-")].to_list())
# ----> 5 effect_sizes, pvalues, std_errors  = build_effect_size_anndata(
#       6     results_dir=os.path.join(data_dir+'results/differential_gene_expression',),
#       7     glob_pattern="*.csv",
#       8     file_pattern="_across_continuous_pseudo_progression_score_DE.csv",
#       9     test="continuous_pseudo_progression_score",
#      10     adata=adata_merged,
#      11     subclass=cell_type_column,
#      12     celltype=cell_type_column,
#      13     blacklisted_genes=blacklisted_genes,
#      14 )
#
# NameError: name 'build_effect_size_anndata' is not defined

# %%
effect_size_table = pd.read_csv('/media/tadeoye/Volume1/data/seq/SEA-AD/MTG/supplementary/Nebula Results/effect_size_table.csv')
effect_size_table
# Out:
#          Unnamed: 0         Gene Taxonomy Level                   Population  \
# 0                 0  MIR1302-2HG      Supertype                 Lamp5_Lhx6_1
# 1                 1      FAM138A      Supertype                 Lamp5_Lhx6_1
# 2                 2        OR4F5      Supertype                 Lamp5_Lhx6_1
# 3                 3   AL627309.1      Supertype                 Lamp5_Lhx6_1
# 4                 4   AL627309.3      Supertype                 Lamp5_Lhx6_1
# ...             ...          ...            ...                          ...
# 6072275     6072275   AC141272.1          Class  Non-neuronal and non-neural
# 6072276     6072276   AC023491.2          Class  Non-neuronal and non-neural
# 6072277     6072277   AC007325.1          Class  Non-neuronal and non-neural
# 6072278     6072278   AC007325.4          Class  Non-neuronal and non-neural
# 6072279     6072279   AC007325.2          Class  Non-neuronal and non-neural
#
#          Effect size across all of pseudoprogression  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                              -2.17
# 4                                               0.00
# ...                                              ...
# 6072275                                         0.00
# 6072276                                         0.00
# 6072277                                         0.03
# 6072278                                         0.47
# 6072279                                         0.42
#
#          Effect size across early pseudoprogression  \
# 0                                              0.00
# 1                                              0.00
# 2                                              0.00
# 3                                             -0.79
# 4                                              0.00
# ...                                             ...
# 6072275                                        0.00
# 6072276                                        0.00
# 6072277                                        0.05
# 6072278                                       -0.04
# 6072279                                       -0.35
#
#          Effect size across late pseudoprogression  \
# 0                                             0.00
# 1                                             0.00
# 2                                             0.00
# 3                                             0.28
# 4                                             0.00
# ...                                            ...
# 6072275                                       0.00
# 6072276                                       0.00
# 6072277                                       0.04
# 6072278                                       0.29
# 6072279                                       0.11
#
#          Mean expression (natural log UMIs per 10k plus 1)
# 0                                                     0.00
# 1                                                     0.00
# 2                                                     0.00
# 3                                                     0.01
# 4                                                     0.00
# ...                                                    ...
# 6072275                                               0.00
# 6072276                                               0.00
# 6072277                                               0.00
# 6072278                                               0.02
# 6072279                                               0.03
#
# [6072280 rows x 8 columns]

# %%
results_dir = os.path.join(data_dir+'results/differential_gene_expression',
                             subclass.capitalize(),
                             factor, 
                             f'{subclass.capitalize()}_{subclass.capitalize()}_across_{factor}_DE.csv')

effect_sizes = get_standardized_effects(results_dir, factor, filter_genes=False, thr = 0.01)
