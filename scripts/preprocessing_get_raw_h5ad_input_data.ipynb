# %%
import os
import rpy2
import logging
import warnings
import anndata2ri
import pandas as pd
import scanpy as sc
import anndata as ad
import numpy as np
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from matplotlib.pyplot import rcParams
import synapseclient
import synapseutils

# %%
# # Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

warnings.filterwarnings("ignore", category=PendingDeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# Automatically convert rpy2 outputs to pandas dataframes
pandas2ri.activate()
anndata2ri.activate()
# %load_ext rpy2.ipython

# rcParams['figure.dpi'] = get_sys_dpi(1512, 982, 14.125)
# rcParams['figure.figsize']=(4,4) #rescale figures

sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.3
# -----
# PIL                         9.5.0
# anndata2ri                  1.1
# appnope                     0.1.3
# asttokens                   NA
# backcall                    0.2.0
# certifi                     2023.05.07
# cffi                        1.15.1
# charset_normalizer          3.1.0
# comm                        0.1.3
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# deprecated                  1.2.14
# executing                   1.2.0
# google                      NA
# h5py                        3.9.0
# idna                        3.4
# igraph                      0.10.4
# ipykernel                   6.23.2
# ipywidgets                  8.0.6
# jedi                        0.18.2
# jinja2                      3.1.2
# joblib                      1.2.0
# kiwisolver                  1.4.4
# leidenalg                   0.9.1
# llvmlite                    0.39.1
# louvain                     0.8.0
# markupsafe                  2.1.3
# matplotlib                  3.7.1
# mpl_toolkits                NA
# natsort                     8.4.0
# numba                       0.56.4
# numexpr                     2.8.4
# numpy                       1.23.5
# opentelemetry               NA
# packaging                   23.1
# pandas                      2.0.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.7.0
# prompt_toolkit              3.0.38
# psutil                      5.9.5
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     12.0.1
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pyparsing                   3.1.0
# pytz                        2023.3
# pytz_deprecation_shim       NA
# requests                    2.31.0
# rpy2                        3.5.12
# scipy                       1.10.1
# session_info                1.0.0
# setuptools                  68.0.0
# six                         1.16.0
# sklearn                     1.2.2
# stack_data                  0.6.2
# synapseclient               4.1.1
# synapseutils                NA
# texttable                   1.6.7
# threadpoolctl               3.1.0
# tornado                     6.3.2
# traitlets                   5.9.0
# typing_extensions           NA
# tzlocal                     NA
# urllib3                     1.26.18
# vscode                      NA
# wcwidth                     0.2.6
# wrapt                       1.15.0
# yaml                        6.0
# zipp                        NA
# zmq                         25.1.0
# zoneinfo                    NA
# -----
# IPython             8.14.0
# jupyter_client      8.2.0
# jupyter_core        5.3.1
# -----
# Python 3.10.6 (main, Oct 24 2022, 11:04:34) [Clang 12.0.0 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2024-04-18 19:55

# %% [markdown]
# # **Load input data in raw form and save in `.h5ad` format**

# %% [markdown]
# ### **List of all datasets present in Gazestani meta-analysis**

# %%
# %%R
#
# library(qs)
# library(dplyr)
# library(SingleCellExperiment)
# library(readxl)
# library(scMerge)
# library(Seurat)
#
# mic_annot <- qread("../data/raw/gazestani_pfc/annotations/MG_Final_anno.qs")
#
# unique(mic_annot$ds_batch)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#      [1] "human_Lake_29227469_VisualCortex" "human_Li_nuclei_30545854"
#  [3] "human_Hodge_31435019"             "human_Bakken_34616062"
#  [5] "mouse_Chen_28355573"              "mouse_Keren-Shaul_28602351"
#  [7] "mouse_SalaFrigerio_exp1_31018141" "mouse_SalaFrigerio_exp2_31018141"
#  [9] "mouse_Masuda_GSE120745"           "mouse_Masuda_GSE120629"
# [11] "mouse_Masuda_GSE120744"           "mouse_Sierksma_31951107"
# [13] "mouse_Yao_34616066_BICCN_sn"      "mouse_Zhou_31932797"
# [15] "mouse_dulken_31270459"            "mouse_Zywitza_30485812"
# [17] "mouse_Hammond_30471926"           "mouse_Hammond_30471926_LPC"
# [19] "mouse_Bhattacherjee_31519873"     "human_Zhou_31932797"
# [21] "human_Leng_33432193"              "human_Gerrits_33609158"
# [23] "human_Smajic_34919646"            "human_NPH"
# [25] "human_Kamath_35513515"            "human_Grubman_31768052"
# [27] "human_Velmeshev_31097668"         "human_Mathys_31042697"
# [29] "human_Lau_32989152"               "human_Jakel_30747918"
# qs 0.25.5
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: SummarizedExperiment
# Loading required package: MatrixGenerics
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
# Attaching package: ‘MatrixGenerics’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: BiocGenerics
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
# Loading required package: S4Vectors
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     I, expand.grid, unname
#
# Loading required package: IRanges
#
# Attaching package: ‘IRanges’
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
# Loading required package: GenomeInfoDb
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘Biobase’
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, were retired in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# Attaching SeuratObject
#
# Attaching package: ‘Seurat’
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
# In addition: Warning messages:
# 1: package ‘MatrixGenerics’ was built under R version 4.3.1
# 2: package ‘S4Vectors’ was built under R version 4.3.1
# 3: package ‘IRanges’ was built under R version 4.3.1
# 4: package ‘GenomeInfoDb’ was built under R version 4.3.1

# %%
def convert_columns_to_string(sce, obs_cols=None, var_cols=None):
    """
    Convert specified columns in the .obs and .var DataFrames of an anndata object to string type.

    Parameters:
    sce (anndata.AnnData): The single-cell AnnData object to modify.
    obs_cols (list of str): Columns in sce.obs to convert to strings.
    var_cols (list of str): Columns in sce.var to convert to strings.
    """
    if obs_cols is not None:
        for col in obs_cols:
            sce.obs[col] = sce.obs[col].astype(str)
    
    if var_cols is not None:
        for col in var_cols:
            sce.var[col] = sce.var[col].astype(str)

def save_anndata(sce, file_path):
    """
    Save an AnnData object to a file.

    Parameters:
    sce (anndata.AnnData): The single-cell AnnData object to save.
    file_path (str): The path to save the file to.
    """
    sce.write_h5ad(file_path, compression='gzip')



def create_minimal_adata(adata_obj, output_file_path, gene_id_column=None):
    """
    Load an .h5ad file, create a minimal AnnData object from it, and save the minimal object.

    Parameters:
    input_file_path (str): Path to the original .h5ad file.
    output_file_path (str): Path where the minimal .h5ad file will be saved.
    gene_id_column (str, optional): Column name in adata.var where gene identifiers are stored. 
                                    If None, it is assumed gene identifiers are stored in adata.var.index.
    """
    try:
        # Load the original .h5ad file
        my_too_large_adata = adata_obj
        
        # Create a minimal AnnData object
        minimal_adata = ad.AnnData(my_too_large_adata.X)
        
        # Set gene identifiers
        if gene_id_column:
            # Option (b): If gene identifiers are stored in a specific column
            minimal_adata.var_names = my_too_large_adata.var[gene_id_column]
        else:
            # Option (a): If gene identifiers are stored in adata.var.index
            minimal_adata.var_names = my_too_large_adata.var_names
        
        # Set observation names
        minimal_adata.obs_names = my_too_large_adata.obs_names
        
        # Save the minimal AnnData object with gzip compression
        minimal_adata.write(output_file_path, compression='gzip')
        
        print(f"Minimal AnnData object has been saved to {output_file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")


# Function to filter and update AnnData object based on cell barcode annotations
def filter_and_update_anndata(ad, annot):

    # Filter valid cell barcodes
    #valid_barcodes = ad.obs_names.intersection()
    ad_filtered = ad[annot['cell_barcode'].to_list()].copy()
    
    # Merge annotations
    ad_filtered.obs = ad_filtered.obs.merge(annot, left_on=ad_filtered.obs_names, right_on='cell_barcode', how='right')
    
    # Update obs_names with cell barcodes
    ad_filtered.obs_names = ad_filtered.obs['cell_barcode']
    
    return ad_filtered

# %% [markdown]
# ## **[Gazestani et. al. 2019](https://doi.org/10.1016/j.cell.2023.08.005) (Prefrontal Cortex)**

# %%
# %%R -o sce_list -o annot_list
#
#
#
# # Function to read data
# read_data <- function(path) {
#   qread(path)
# }
#
# # Function to filter annotations based on ds_batch
# filter_annotations <- function(annot, batch = 'human_NPH') {
#   annot %>% filter(ds_batch == batch)
# }
#
# # Function to transform sample column
# transform_sample <- function(sample_column, start_ind=3) {
#   sapply(sample_column, function(x) {
#     paste(unlist(strsplit(x, "_"))[start_ind:length(unlist(strsplit(x, "_")))], collapse = "_")
#   })
# }
#
# # Function to subset SCE objects based on valid columns
# subset_sce <- function(sce, annot) {
#   valid_cols <- colnames(sce)[!is.na(match(colnames(sce), annot$cell_barcode))]
#   sce[, valid_cols]
# }
#
# # Function to merge annotations with SCE object
# merge_annotations <- function(sce, annot) {
#   colData(sce)$cell_barcode <- colnames(sce)
#   colData(sce) <- DataFrame(as(colData(sce), "data.frame") %>%
#                             right_join(annot, by = "cell_barcode"))
#   colnames(sce) <- colData(sce)$cell_barcode
#   return(sce)
# }
#
# # Paths
# base_path <- "../data/raw/gazestani_pfc/organized_data/Human/brain/snRNA/Gazestani_0001"
# annotation_path <- "../data/raw/gazestani_pfc/annotations"
#
# # Cell types and annotations
# cell_types <- c("Astro", "Endo", "ExN", "InN", "MG", "Oligo", "OPC")
# annotations <- paste0(cell_types, "_Final_anno.qs")
#
# # Read and filter data
# sce_list <- lapply(paste0(base_path, "/", cell_types, "_data_arranged_updatedId_final_batches.qs"), read_data)
# annot_list <- lapply(paste0(annotation_path, "/", annotations), read_data)
# annot_list <- lapply(annot_list, filter_annotations)
#
# # Assign names to lists
# names(sce_list) <- cell_types
# names(annot_list) <- cell_types
#
# # Transform sample column, subset SCE objects, and merge annotations
# for (cell_type in cell_types) {
#   annot_list[[cell_type]]$cell_barcode <- transform_sample(annot_list[[cell_type]]$sample)
#   sce_list[[cell_type]] <- subset_sce(sce_list[[cell_type]], annot_list[[cell_type]])
#   sce_list[[cell_type]] <- merge_annotations(sce_list[[cell_type]], annot_list[[cell_type]])
# }

# %%
dat_dir = f'../data/raw/gazestani_pfc/anndata/minimal/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)


# Define the columns to convert for obs and var
obs_columns_to_convert = ['anno_braak_score']
var_columns_to_convert = ['entrezid']

# Define the SCE objects and their corresponding file paths
sce_objects = sce_list

file_paths = {
    'ExN': "../data/raw/gazestani_pfc/anndata/excitatory_raw_anndata.h5ad",
    'InN': "../data/raw/gazestani_pfc/anndata/inhibitory_raw_anndata.h5ad",
    'Astro': "../data/raw/gazestani_pfc/anndata/astrocyte_raw_anndata.h5ad",
    'MG': "../data/raw/gazestani_pfc/anndata/microglia_raw_anndata.h5ad",
    'Oligo': "../data/raw/gazestani_pfc/anndata/oligodendrocyte_raw_anndata.h5ad",
    'OPC': "../data/raw/gazestani_pfc/anndata/opc_raw_anndata.h5ad",
    'Endo': "../data/raw/gazestani_pfc/anndata/endothelial_raw_anndata.h5ad"
}

# Loop through SCE objects to convert column types and save them
for sce_name, sce_obj in sce_objects.items():
    sce_obj.obs['individualID'] = sce_obj.obs['anno_batch.x'].apply(lambda x: x.split('_')[-1])
    sce_obj.obs.Subclass = sce_obj.obs.anno_ctype.apply(lambda x: x.split('_')[0])
    sce_obj.obs.Supertype = sce_obj.obs.anno_ctype
    convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
    save_anndata(sce_obj, file_paths[sce_name])
    # create_minimal_adata(sce_obj, '/'.join(file_paths[sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[sce_name].split('/')[-1]]))

# %%
metadata = pd.read_excel('../data/raw/gazestani_pfc/full_meta.xlsx')
metadata['pathology.group'] = metadata.Status.map({'Abeta': "early", 'AbetaTau': 'late', 'Ctrl': 'no'})
metadata['individualID'] = metadata['Sbj code'].astype(str)

metadata.to_csv('../data/raw/gazestani_pfc/gazestani_pfc_metadata.csv')

# %% [markdown]
# ## **[Gerrits et. al. 2021](https://link.springer.com/article/10.1007/s00401-021-02263-w) (Occipital Cortex)**

# %%
# %%R -o sce_list -o annot_list
#
# # Function to transform sample column
# transform_sample <- function(sample_column, start_ind=3) {
#   sapply(sample_column, function(x) {
#     paste(unlist(strsplit(x, "_"))[start_ind:length(unlist(strsplit(x, "_")))], collapse = "_")
#   })
# }
#
# # Paths
# base_path <- "../data/raw/gazestani_pfc/organized_data/Human/brain/snRNA/Gerrits_33609158"
# annotation_path <- "../data/raw/gazestani_pfc/annotations"
#
# # Cell types and annotations
# cell_types <- c("MG")
# annotations <- paste0(cell_types, "_Final_anno.qs")
#
# # Read and filter data
# sce_list <- lapply(paste0(base_path, "/", cell_types, "_data_arranged_updatedId_final_batches.qs"), read_data)
# annot_list <- lapply(paste0(annotation_path, "/", annotations), read_data)
# annot_list <- lapply(annot_list, function(x) filter_annotations(x, batch = 'human_Gerrits_33609158'))
#
#
# # Assign names to lists
# names(sce_list) <- cell_types
# names(annot_list) <- cell_types
#
# # Transform sample column, subset SCE objects, and merge annotations
# for (cell_type in cell_types) {
#   annot_list[[cell_type]]$cell_barcode <- transform_sample(annot_list[[cell_type]]$sample, 4)
#   sce_list[[cell_type]] <- subset_sce(sce_list[[cell_type]], annot_list[[cell_type]])
#   sce_list[[cell_type]] <- merge_annotations(sce_list[[cell_type]], annot_list[[cell_type]])
# }

# %%
dat_dir = f'../data/raw/gerrits_otc/anndata/minimal/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)

# Define the columns to convert for obs and var
obs_columns_to_convert = ['anno_braak_score', 'anno_orig_cellState']
var_columns_to_convert = ['entrezid']

# Define the SCE objects and their corresponding file paths
sce_objects = sce_list

file_paths = {
    'MG': "../data/raw/gerrits_otc/anndata/microglia_raw_anndata.h5ad",
}

# Loop through SCE objects to convert column types and save them
for sce_name, sce_obj in sce_objects.items():
    convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
    save_anndata(sce_obj, file_paths[sce_name])
    create_minimal_adata(sce_obj, '/'.join(file_paths[sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[sce_name].split('/')[-1]]))
# Out:
# Minimal AnnData object has been saved to ../data/raw/gerrits_otc/anndata/minimal_microglia_raw_anndata.h5ad

# %%
metadata = sce_list['MG'].obs.drop_duplicates(subset='title', keep='first')
metadata['pathology.group'] = metadata['sample.group.ch1'].map({'CTR+': "early", 'AD': 'late', 'CTR': 'no'})
metadata['individualID'] = metadata.title.astype(str)

metadata.to_csv('../data/raw/gerrits_otc/gerrits_otc_metadata.csv')
# Out:
# /var/folders/70/42xwxjh94x5f164djlw1hwpc0000gv/T/ipykernel_27680/2133377725.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['pathology_group'] = metadata['sample.group.ch1'].map({'CTR+': "early", 'AD': 'late', 'CTR': 'no'})
# /var/folders/70/42xwxjh94x5f164djlw1hwpc0000gv/T/ipykernel_27680/2133377725.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['individualID'] = metadata.title.astype(str)

# %% [markdown]
# ## **[Mathys et. al. 2019](https://www.nature.com/articles/s41586-019-1195-2) (Prefrontal Cortex)**

# %%
# %%R -o annot_list
#
# # Paths
# annotation_path <- "../data/raw/gazestani_pfc/annotations"
#
# # Cell types and annotations
# cell_types <- c("Astro", "Endo", "ExN", "InN", "MG", "Oligo", "OPC")
# annotations <- paste0(cell_types, "_Final_anno.qs")
#
# # Read and filter data
# annot_list <- lapply(paste0(annotation_path, "/", annotations), read_data)
# annot_list <- lapply(annot_list, function(x) filter_annotations(x, batch = 'human_Mathys_31042697'))
#
# # Assign names to lists
# names(annot_list) <- cell_types
#
# # Transform sample column, subset SCE objects, and merge annotations
# for (cell_type in cell_types) {
#   annot_list[[cell_type]]$cell_barcode <- transform_sample(annot_list[[cell_type]]$sample, 4)
# }

# %%
adata = sc.read_mtx('../data/raw/mathys_pfc/notfiltered_count_matrix.mtx').T

obs_names = pd.read_csv('../data/raw/mathys_pfc/notfiltered_column_metadata.txt', sep='\t')
obs_names.TAG = obs_names.TAG.str.replace('.', '-')
obs_names.set_index('TAG', inplace=True)
obs_names.index.rename('index', inplace=True)

gene_names = pd.read_csv('../data/raw/mathys_pfc/notfiltered_gene_row_names.txt', sep='\t', header=None)

adata.obs = obs_names
adata.var_names = gene_names[1]


sce_list = {}
for cell_type, annot in annot_list.items():
    if len(annot_list[cell_type])>0:
        sce_list[cell_type] = filter_and_update_anndata(adata, annot_list[cell_type])

# %%
dat_dir = f'../data/raw/mathys_pfc/anndata/minimal/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)

# Define the columns to convert for obs and var
obs_columns_to_convert = ['anno_braak_score']
var_columns_to_convert = None

# Define the SCE objects and their corresponding file paths
sce_objects = sce_list

file_paths = {
    'ExN': "../data/raw/mathys_pfc/anndata/excitatory_raw_anndata.h5ad",
    'InN': "../data/raw/mathys_pfc/anndata/inhibitory_raw_anndata.h5ad",
    'Astro': "../data/raw/mathys_pfc/anndata/astrocyte_raw_anndata.h5ad",
    'MG': "../data/raw/mathys_pfc/anndata/microglia_raw_anndata.h5ad",
    'Oligo': "../data/raw/mathys_pfc/anndata/oligodendrocyte_raw_anndata.h5ad",
    'OPC': "../data/raw/mathys_pfc/anndata/opc_raw_anndata.h5ad",
    'Endo': "../data/raw/mathys_pfc/anndata/endothelial_raw_anndata.h5ad"
}

# Loop through SCE objects to convert column types and save them
for sce_name, sce_obj in sce_objects.items():
    sce_obj.var_names_make_unique()
    convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
    save_anndata(sce_obj, file_paths[sce_name])   
    create_minimal_adata(sce_obj, '/'.join(file_paths[sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[sce_name].split('/')[-1]]))
# Out:
# Minimal AnnData object has been saved to ../data/raw/mathys_pfc/anndata/minimal_astrocyte_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/mathys_pfc/anndata/minimal_excitatory_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/mathys_pfc/anndata/minimal_inhibitory_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/mathys_pfc/anndata/minimal_microglia_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/mathys_pfc/anndata/minimal_oligodendrocyte_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/mathys_pfc/anndata/minimal_opc_raw_anndata.h5ad

# %%
metadata = sce_list['Astro'].obs.drop_duplicates(subset='projid', keep='first')
metadata['pathology.group'] = metadata['anno_braak_score'].map({'3': "early", '4': 'early', '5': 'late', '6': 'late', '0': 'no', '1': 'no', '2': 'no'})
metadata['individualID'] = metadata.projid.astype(str)

metadata.to_csv('../data/raw/mathys_pfc/mathys_pfc_metadata.csv')
# Out:
# /var/folders/70/42xwxjh94x5f164djlw1hwpc0000gv/T/ipykernel_27680/4054192223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['pathology_group'] = metadata['anno_braak_score'].map({'3': "early", '4': 'early', '5': 'late', '6': 'late', '0': 'no', '1': 'no', '2': 'no'})
# /var/folders/70/42xwxjh94x5f164djlw1hwpc0000gv/T/ipykernel_27680/4054192223.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['individualID'] = metadata.projid.astype(str)

# %% [markdown]
# ## **[Leng et. al. 2021](https://www.nature.com/articles/s41593-020-00764-7) (Superior Frontal Gyrus & Entorhinal Cortex)**

# %%
# %%R -o annot_list
#
# # Paths
# annotation_path <- "../data/raw/gazestani_pfc/annotations"
#
# # Cell types and annotations
# cell_types <- c("Astro", "Endo", "ExN", "InN", "MG", "Oligo", "OPC")
# annotations <- paste0(cell_types, "_Final_anno.qs")
#
# # Read and filter data
# annot_list <- lapply(paste0(annotation_path, "/", annotations), read_data)
# annot_list <- lapply(annot_list, function(x) filter_annotations(x, batch = 'human_Leng_33432193'))
#
# # Assign names to lists
# names(annot_list) <- cell_types
#
# # Transform sample column, subset SCE objects, and merge annotations
# for (cell_type in cell_types) {
#   annot_list[[cell_type]]$cell_barcode <- transform_sample(annot_list[[cell_type]]$sample, 4)
# }

# %%
# processed data obtained 
adata_leng = {}

readRDS = robjects.r['readRDS']
df_etc = readRDS('../data/raw/leng_etc/sce.EC.scAlign.assigned.rds')
adata_leng['etc'] = df_etc

# processed data obtained 
readRDS = robjects.r['readRDS']
df_sfg = readRDS('../data/raw/leng_sfg/sce.SFG.scAlign.assigned.rds')
adata_leng['sfg'] = df_sfg

cell_types = ['Exc', 'Inh', 'Astro', 'Endo', 'Micro', 'OPC', 'Oligo']

# %%
dat_dir = {'etc': f'../data/raw/leng_etc/anndata/minimal/', 'sfg': f'../data/raw/leng_sfg/anndata/minimal/'}


# Define the columns to convert for obs and var
obs_columns_to_convert = None
var_columns_to_convert = None

file_paths = {
    'etc': {
        'Exc': "../data/raw/leng_etc/anndata/excitatory_raw_anndata.h5ad",
        'Inh': "../data/raw/leng_etc/anndata/inhibitory_raw_anndata.h5ad",
        'Astro': "../data/raw/leng_etc/anndata/astrocyte_raw_anndata.h5ad",
        'Micro': "../data/raw/leng_etc/anndata/microglia_raw_anndata.h5ad",
        'Oligo': "../data/raw/leng_etc/anndata/oligodendrocyte_raw_anndata.h5ad",
        'OPC': "../data/raw/leng_etc/anndata/opc_raw_anndata.h5ad",
        'Endo': "../data/raw/leng_etc/anndata/endothelial_raw_anndata.h5ad"
        },

    'sfg':
        {   
        'Exc': "../data/raw/leng_sfg/anndata/excitatory_raw_anndata.h5ad",
        'Inh': "../data/raw/leng_sfg/anndata/inhibitory_raw_anndata.h5ad",
        'Astro': "../data/raw/leng_sfg/anndata/astrocyte_raw_anndata.h5ad",
        'Micro': "../data/raw/leng_sfg/anndata/microglia_raw_anndata.h5ad",
        'Oligo': "../data/raw/leng_sfg/anndata/oligodendrocyte_raw_anndata.h5ad",
        'OPC': "../data/raw/leng_sfg/anndata/opc_raw_anndata.h5ad",
        'Endo': "../data/raw/leng_sfg/anndata/endothelial_raw_anndata.h5ad"
        }
    }

for brain_region in ['etc', 'sfg']:

    if not os.path.exists(dat_dir[brain_region]):
        os.makedirs(dat_dir[brain_region])

    for sce_name in cell_types:
        sce_obj = adata_leng[brain_region][adata_leng[brain_region].obs.clusterCellType==sce_name]
        convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
        save_anndata(sce_obj, file_paths[brain_region][sce_name])   
        create_minimal_adata(sce_obj, '/'.join(file_paths[brain_region][sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[brain_region][sce_name].split('/')[-1]]))
# Out:
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_excitatory_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_inhibitory_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_astrocyte_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_endothelial_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_microglia_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_opc_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_etc/anndata/minimal_oligodendrocyte_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_excitatory_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_inhibitory_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_astrocyte_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_endothelial_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_microglia_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_opc_raw_anndata.h5ad
# Minimal AnnData object has been saved to ../data/raw/leng_sfg/anndata/minimal_oligodendrocyte_raw_anndata.h5ad

# %% [markdown]
# ## **[Gabitto et. al. 2021](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10246227/) (Middle Temporal Gyrus - RNA-seq)**

# %%
adata = sc.read_h5ad('../data/raw/SEA-AD/MTG/RNASeq/SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad')

adata.obs['cell_type'] = adata.obs['Subclass'].copy()
adata.obs['cell_type'] = adata.obs['cell_type'].astype(str)
adata.obs.loc[adata.obs['Class'].str.startswith("Neuronal:"), 'cell_type'] = adata.obs['Class'][adata.obs['Class'].str.startswith("Neuronal:")].map({"Neuronal: Glutamatergic": "Excitatory",
                                                                "Neuronal: GABAergic": "Inhibitory"})

adata.obs.loc[adata.obs.cell_type=='Microglia-PVM', 'cell_type'] = 'Microglia'
adata.obs['cell_type'] = adata.obs['cell_type'].astype('category')

adata.layers['counts'] = adata.layers['nUMIs']

# %%
dat_dir = f'../data/raw/seaad_mtg/anndata/rna/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)

# Define the columns to convert for obs and var
obs_columns_to_convert = None
var_columns_to_convert = None

# Define the SCE objects and their corresponding file paths

file_paths = {
    'Excitatory': "../data/raw/seaad_mtg/anndata/rna/excitatory_raw_anndata.h5ad",
    'Inhibitory': "../data/raw/seaad_mtg/anndata/rna/inhibitory_raw_anndata.h5ad",
    'Astrocyte': "../data/raw/seaad_mtg/anndata/rna/astrocyte_raw_anndata.h5ad",
    'Microglia': "../data/raw/seaad_mtg/anndata/rna/microglia_raw_anndata.h5ad",
    'Oligodendrocyte': "../data/raw/seaad_mtg/anndata/rna/oligodendrocyte_raw_anndata.h5ad",
    'OPC': "../data/raw/seaad_mtg/anndata/rna/opc_raw_anndata.h5ad",
    'Endothelial': "../data/raw/seaad_mtg/anndata/rna/endothelial_raw_anndata.h5ad",
    'VLMC': "../data/raw/seaad_mtg/anndata/nra/vlmc_raw_anndata.h5ad"
}


for sce_name in adata.obs.cell_type.unique():
    sce_obj = adata[adata.obs.cell_type==sce_name]
    convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
    save_anndata(sce_obj, file_paths[sce_name])   
    # create_minimal_adata(sce_obj, '/'.join(file_paths[sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[sce_name].split('/')[-1]]))

# %% [markdown]
# ## **[Gabitto et. al. 2021](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10246227/) (Middle Temporal Gyrus - ATAC-Seq)**

# %%
adata = sc.read_h5ad('../data/raw/SEA-AD/MTG/ATACseq/SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad')

adata.obs['cell_type'] = adata.obs['Subclass'].copy()
adata.obs['cell_type'] = adata.obs['cell_type'].astype(str)
adata.obs.loc[adata.obs['Class'].str.startswith("Neuronal:"), 'cell_type'] = adata.obs['Class'][adata.obs['Class'].str.startswith("Neuronal:")].map({"Neuronal: Glutamatergic": "Excitatory",
                                                                "Neuronal: GABAergic": "Inhibitory"})

adata.obs.loc[adata.obs.cell_type=='Microglia-PVM', 'cell_type'] = 'Microglia'
adata.obs['cell_type'] = adata.obs['cell_type'].astype('category')

# %%
dat_dir = f'../data/raw/seaad_mtg/anndata/atac/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)

# Define the columns to convert for obs and var
obs_columns_to_convert = None
var_columns_to_convert = None

# Define the SCE objects and their corresponding file paths

file_paths = {
    'Excitatory': "../data/raw/seaad_mtg/anndata/atac/excitatory_raw_anndata.h5ad",
    'Inhibitory': "../data/raw/seaad_mtg/anndata/atac/inhibitory_raw_anndata.h5ad",
    'Astrocyte': "../data/raw/seaad_mtg/anndata/atac/astrocyte_raw_anndata.h5ad",
    'Microglia': "../data/raw/seaad_mtg/anndata/atac/microglia_raw_anndata.h5ad",
    'Oligodendrocyte': "../data/raw/seaad_mtg/anndata/atac/oligodendrocyte_raw_anndata.h5ad",
    'OPC': "../data/raw/seaad_mtg/anndata/atac/opc_raw_anndata.h5ad",
    'Endothelial': "../data/raw/seaad_mtg/anndata/atac/endothelial_raw_anndata.h5ad",
    'VLMC': "../data/raw/seaad_mtg/anndata/atac/vlmc_raw_anndata.h5ad"
}


for sce_name in adata.obs.cell_type.unique():
    sce_obj = adata[adata.obs.cell_type==sce_name]
    convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
    save_anndata(sce_obj, file_paths[sce_name])   
    # create_minimal_adata(sce_obj, '/'.join(file_paths[sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[sce_name].split('/')[-1]]))

# %% [markdown]
# ## **[Gabitto et. al. 2021](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10246227/) (Middle Temporal Gyrus - Raw Fragments File)**

# %%
token = "eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..pXoRdUHD1rXCvalb9RtQbvcNal0mGsHZM77YZ6imofGnEe-ehPkL4CbTFFJLEmgv-PvdCcrc5xRjY0oy8lO8xbw-CgUyiCSYAWw8QJZk-7ctAnHljMRG5SpBW5PFlWIVbHUe8G0hpfZusp3CNxUOMoiFrWysktPR1zQUhSv-dvDDDj1qePcjAllhLSTQiyAOmhJ20VJT_y6rMLWf5kkTpOwyDPgHUT9iO2nECkyPq9nVhd8aopTbFUsH9L6MRmIaWgDJi4C0spu9cUvhrIvJceWdu9lWLS1AaDdXk-I3SDeiyIMk8_YLgfoELLi_36OE-6bsB3D0XbhArWgmizpXqg"
syn = synapseclient.login(authToken=token)

dat_dir = '/Volumes/Seagate/SEA-AD/MTG/ATACseq/fragments/' #f'../data/raw/SEA-AD/MTG/ATACseq/fragments/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)
# Out:
# Welcome, tadeoye_usf!

# %%
syn.get_annotations('syn31145995')
# Out:
# {'sex': ['male'],
#  'assay': ['snATACSeq'],
#  'grant': ['U19AG060909'],
#  'organ': ['brain'],
#  'study': ['SEA-AD'],
#  'tissue': ['middle temporal gyrus'],
#  'runType': ['pairedEnd'],
#  'species': ['Human'],
#  'dataType': ['epigenetics'],
#  'platform': ['IlluminaNovaseq6000'],
#  'consortium': ['CDCP'],
#  'fileFormat': ['gzip'],
#  'isMultiome': [False],
#  'readLength': ['50bp'],
#  'specimenID': ['M2AT_210806_201_B01'],
#  'dataSubtype': ['processed'],
#  'individualID': ['H20.33.001'],
#  'resourceType': ['experimentalData'],
#  'isModelSystem': [False],
#  'isMultiSpecimen': [False],
#  'nucleicAcidSource': ['single nucleus']}

# %%
my_project_id = 'syn28257487'
fragment_ids = []

annotations = {key: [] for key in syn.get_annotations('syn31145995').keys()}
annotations['synapseID'] = []
annotations['fileID'] = []

for directory_path, directory_names, file_name in synapseutils.walk(syn=syn, synId=my_project_id, includeTypes=["file"]):
    for directory_name in directory_names:
        print(f"Directory ({directory_name[1]}): {directory_path[0]}/{directory_name[0]}")

    for file in file_name:

        # download fragment files
        if file[0].endswith('.tsv.gz'):
            print(f"File ({file[1]}): {directory_path[0]}/{file[0]}")

            # include file annotations for metadata construction

            for key in syn.get_annotations(file[1]):
                annotations[key].append(syn.get_annotations(file[1])[key][0])
            annotations['synapseID'].append(file[1])
            annotations['fileID'].append(file[0].split('-')[0])
            fragment_ids.append(file[1])

            if file[0] not in os.listdir(dat_dir):
                fragment_files = synapseutils.syncFromSynapse(syn, file[1], path=dat_dir, manifest='root')
                
        # download index files 
        elif file[0].endswith('.tsv.gz.tbi'):
            print(f"File ({file[1]}): {directory_path[0]}/{file[0]}")
            if file[0] not in os.listdir(dat_dir):
                fragment_files = synapseutils.syncFromSynapse(syn, file[1], path=dat_dir, manifest='root')
# Out:
# File (syn31147175): snATACseq - MTG/1064293374-fragments.tsv.gz
# File (syn31149030): snATACseq - MTG/1064293374-fragments.tsv.gz.tbi
# File (syn31147232): snATACseq - MTG/1064293376-fragments.tsv.gz
# File (syn31149031): snATACseq - MTG/1064293376-fragments.tsv.gz.tbi
# File (syn31146781): snATACseq - MTG/1064293377-fragments.tsv.gz
# File (syn31149025): snATACseq - MTG/1064293377-fragments.tsv.gz.tbi
# File (syn31146806): snATACseq - MTG/1064293378-fragments.tsv.gz
# File (syn31149029): snATACseq - MTG/1064293378-fragments.tsv.gz.tbi
# File (syn31146935): snATACseq - MTG/1064293379-fragments.tsv.gz
# File (syn31149032): snATACseq - MTG/1064293379-fragments.tsv.gz.tbi
# File (syn31147162): snATACseq - MTG/1074937000-fragments.tsv.gz
# File (syn31149035): snATACseq - MTG/1074937000-fragments.tsv.gz.tbi
# File (syn31147195): snATACseq - MTG/1074937004-fragments.tsv.gz
# File (syn31149036): snATACseq - MTG/1074937004-fragments.tsv.gz.tbi
# File (syn31147252): snATACseq - MTG/1074937005-fragments.tsv.gz
# File (syn31149038): snATACseq - MTG/1074937005-fragments.tsv.gz.tbi
# File (syn31147277): snATACseq - MTG/1074937006-fragments.tsv.gz
# File (syn31149037): snATACseq - MTG/1074937006-fragments.tsv.gz.tbi
# File (syn31147150): snATACseq - MTG/1075757819-fragments.tsv.gz
# File (syn31149034): snATACseq - MTG/1075757819-fragments.tsv.gz.tbi
# File (syn31147269): snATACseq - MTG/1123939343-fragments.tsv.gz
# File (syn31149040): snATACseq - MTG/1123939343-fragments.tsv.gz.tbi
# File (syn31147058): snATACseq - MTG/1123939344-fragments.tsv.gz
# File (syn31149026): snATACseq - MTG/1123939344-fragments.tsv.gz.tbi
# File (syn31147355): snATACseq - MTG/1126220030-fragments.tsv.gz
# File (syn31149047): snATACseq - MTG/1126220030-fragments.tsv.gz.tbi
# File (syn31145995): snATACseq - MTG/1126220031-fragments.tsv.gz
# File (syn31149002): snATACseq - MTG/1126220031-fragments.tsv.gz.tbi
# File (syn31146070): snATACseq - MTG/1126220032-fragments.tsv.gz
# File (syn31149022): snATACseq - MTG/1126220032-fragments.tsv.gz.tbi
# File (syn31147536): snATACseq - MTG/1126220033-fragments.tsv.gz
# File (syn31149061): snATACseq - MTG/1126220033-fragments.tsv.gz.tbi
# File (syn31147614): snATACseq - MTG/1129176225-fragments.tsv.gz
# File (syn31149056): snATACseq - MTG/1129176225-fragments.tsv.gz.tbi
# File (syn31148052): snATACseq - MTG/1129176226-fragments.tsv.gz
# File (syn31149078): snATACseq - MTG/1129176226-fragments.tsv.gz.tbi
# File (syn31147521): snATACseq - MTG/1131257166-fragments.tsv.gz
# File (syn31149051): snATACseq - MTG/1131257166-fragments.tsv.gz.tbi
# File (syn31147910): snATACseq - MTG/1131409693-fragments.tsv.gz
# File (syn31149069): snATACseq - MTG/1131409693-fragments.tsv.gz.tbi
# File (syn31146099): snATACseq - MTG/1131409697-fragments.tsv.gz
# File (syn31149023): snATACseq - MTG/1131409697-fragments.tsv.gz.tbi
# File (syn31148396): snATACseq - MTG/1135042880-fragments.tsv.gz
# File (syn31149087): snATACseq - MTG/1135042880-fragments.tsv.gz.tbi
# File (syn31146136): snATACseq - MTG/1135042881-fragments.tsv.gz
# File (syn31149027): snATACseq - MTG/1135042881-fragments.tsv.gz.tbi
# File (syn31147951): snATACseq - MTG/1136687631-fragments.tsv.gz
# File (syn31149079): snATACseq - MTG/1136687631-fragments.tsv.gz.tbi
# File (syn31148091): snATACseq - MTG/1136687632-fragments.tsv.gz
# File (syn31149074): snATACseq - MTG/1136687632-fragments.tsv.gz.tbi
# File (syn31147473): snATACseq - MTG/1138433801-fragments.tsv.gz
# File (syn31149055): snATACseq - MTG/1138433801-fragments.tsv.gz.tbi
# File (syn31147916): snATACseq - MTG/1138433802-fragments.tsv.gz
# File (syn31149059): snATACseq - MTG/1138433802-fragments.tsv.gz.tbi
# File (syn31147906): snATACseq - MTG/1140028668-fragments.tsv.gz
# File (syn31149064): snATACseq - MTG/1140028668-fragments.tsv.gz.tbi
# File (syn31147814): snATACseq - MTG/1140028669-fragments.tsv.gz
# File (syn31149060): snATACseq - MTG/1140028669-fragments.tsv.gz.tbi
# File (syn31147857): snATACseq - MTG/1140028670-fragments.tsv.gz
# File (syn31149070): snATACseq - MTG/1140028670-fragments.tsv.gz.tbi
# File (syn31148042): snATACseq - MTG/1140028671-fragments.tsv.gz
# File (syn31149073): snATACseq - MTG/1140028671-fragments.tsv.gz.tbi
# File (syn31146240): snATACseq - MTG/1140030208-fragments.tsv.gz
# File (syn31149003): snATACseq - MTG/1140030208-fragments.tsv.gz.tbi
# File (syn31147911): snATACseq - MTG/1140030209-fragments.tsv.gz
# File (syn31149066): snATACseq - MTG/1140030209-fragments.tsv.gz.tbi
# File (syn31147283): snATACseq - MTG/1140030210-fragments.tsv.gz
# File (syn31149039): snATACseq - MTG/1140030210-fragments.tsv.gz.tbi
# File (syn31148122): snATACseq - MTG/1140030211-fragments.tsv.gz
# File (syn31149072): snATACseq - MTG/1140030211-fragments.tsv.gz.tbi
# File (syn31147330): snATACseq - MTG/1140885932-fragments.tsv.gz
# File (syn31149053): snATACseq - MTG/1140885932-fragments.tsv.gz.tbi
# File (syn31146082): snATACseq - MTG/1140885933-fragments.tsv.gz
# File (syn31149021): snATACseq - MTG/1140885933-fragments.tsv.gz.tbi
# File (syn31146706): snATACseq - MTG/1140885934-fragments.tsv.gz
# File (syn31149028): snATACseq - MTG/1140885934-fragments.tsv.gz.tbi
# File (syn31146030): snATACseq - MTG/1140885935-fragments.tsv.gz
# File (syn31149024): snATACseq - MTG/1140885935-fragments.tsv.gz.tbi
# File (syn31147343): snATACseq - MTG/1142534944-fragments.tsv.gz
# File (syn31149049): snATACseq - MTG/1142534944-fragments.tsv.gz.tbi
# File (syn31147766): snATACseq - MTG/1142534945-fragments.tsv.gz
# File (syn31149063): snATACseq - MTG/1142534945-fragments.tsv.gz.tbi
# File (syn31147437): snATACseq - MTG/1142534946-fragments.tsv.gz
# File (syn31149050): snATACseq - MTG/1142534946-fragments.tsv.gz.tbi
# File (syn31148136): snATACseq - MTG/1142534947-fragments.tsv.gz
# File (syn31149082): snATACseq - MTG/1142534947-fragments.tsv.gz.tbi
# File (syn31145958): snATACseq - MTG/1142534948-fragments.tsv.gz
# File (syn31149019): snATACseq - MTG/1142534948-fragments.tsv.gz.tbi
# File (syn31145981): snATACseq - MTG/1142534949-fragments.tsv.gz
# File (syn31149020): snATACseq - MTG/1142534949-fragments.tsv.gz.tbi
# File (syn31147412): snATACseq - MTG/1142581752-fragments.tsv.gz
# File (syn31149052): snATACseq - MTG/1142581752-fragments.tsv.gz.tbi
# File (syn31148108): snATACseq - MTG/1142581753-fragments.tsv.gz
# File (syn31149085): snATACseq - MTG/1142581753-fragments.tsv.gz.tbi
# File (syn31147458): snATACseq - MTG/1142581754-fragments.tsv.gz
# File (syn31149041): snATACseq - MTG/1142581754-fragments.tsv.gz.tbi
# File (syn31147449): snATACseq - MTG/1142581755-fragments.tsv.gz
# File (syn31149057): snATACseq - MTG/1142581755-fragments.tsv.gz.tbi
# File (syn31147394): snATACseq - MTG/1142581756-fragments.tsv.gz
# File (syn31149043): snATACseq - MTG/1142581756-fragments.tsv.gz.tbi
# File (syn31147488): snATACseq - MTG/1142581757-fragments.tsv.gz
# File (syn31149042): snATACseq - MTG/1142581757-fragments.tsv.gz.tbi
# File (syn31147509): snATACseq - MTG/1143360947-fragments.tsv.gz
# File (syn31149045): snATACseq - MTG/1143360947-fragments.tsv.gz.tbi
# File (syn31147675): snATACseq - MTG/1143360948-fragments.tsv.gz
# File (syn31149046): snATACseq - MTG/1143360948-fragments.tsv.gz.tbi
# File (syn31147639): snATACseq - MTG/1143360949-fragments.tsv.gz
# File (syn31149048): snATACseq - MTG/1143360949-fragments.tsv.gz.tbi
# File (syn31147592): snATACseq - MTG/1143360950-fragments.tsv.gz
# File (syn31149058): snATACseq - MTG/1143360950-fragments.tsv.gz.tbi
# File (syn31147914): snATACseq - MTG/1143360951-fragments.tsv.gz
# File (syn31149062): snATACseq - MTG/1143360951-fragments.tsv.gz.tbi
# File (syn31148308): snATACseq - MTG/1143360952-fragments.tsv.gz
# File (syn31149077): snATACseq - MTG/1143360952-fragments.tsv.gz.tbi
# File (syn31148348): snATACseq - MTG/1143360953-fragments.tsv.gz
# File (syn31149076): snATACseq - MTG/1143360953-fragments.tsv.gz.tbi
# File (syn31147366): snATACseq - MTG/1144788667-fragments.tsv.gz
# File (syn31149044): snATACseq - MTG/1144788667-fragments.tsv.gz.tbi
# File (syn31148380): snATACseq - MTG/1145495811-fragments.tsv.gz
# File (syn31149080): snATACseq - MTG/1145495811-fragments.tsv.gz.tbi
# File (syn31147564): snATACseq - MTG/1145495812-fragments.tsv.gz
# File (syn31149065): snATACseq - MTG/1145495812-fragments.tsv.gz.tbi
# File (syn31148192): snATACseq - MTG/1145495813-fragments.tsv.gz
# File (syn31149088): snATACseq - MTG/1145495813-fragments.tsv.gz.tbi
# File (syn31148251): snATACseq - MTG/1145495814-fragments.tsv.gz
# File (syn31149084): snATACseq - MTG/1145495814-fragments.tsv.gz.tbi
# File (syn31148229): snATACseq - MTG/1146036866-fragments.tsv.gz
# File (syn31149081): snATACseq - MTG/1146036866-fragments.tsv.gz.tbi
# File (syn31148272): snATACseq - MTG/1146036867-fragments.tsv.gz
# File (syn31149092): snATACseq - MTG/1146036867-fragments.tsv.gz.tbi
# File (syn31147714): snATACseq - MTG/1149386627-fragments.tsv.gz
# File (syn31149054): snATACseq - MTG/1149386627-fragments.tsv.gz.tbi
# File (syn31148034): snATACseq - MTG/1149386628-fragments.tsv.gz
# File (syn31149067): snATACseq - MTG/1149386628-fragments.tsv.gz.tbi
# File (syn31148078): snATACseq - MTG/1149689563-fragments.tsv.gz
# File (syn31149068): snATACseq - MTG/1149689563-fragments.tsv.gz.tbi
# File (syn31148494): snATACseq - MTG/1149689564-fragments.tsv.gz
# File (syn31149075): snATACseq - MTG/1149689564-fragments.tsv.gz.tbi
# File (syn31148427): snATACseq - MTG/1149689565-fragments.tsv.gz
# File (syn31149086): snATACseq - MTG/1149689565-fragments.tsv.gz.tbi
# File (syn31148747): snATACseq - MTG/1149689566-fragments.tsv.gz
# File (syn31149091): snATACseq - MTG/1149689566-fragments.tsv.gz.tbi
# File (syn31148616): snATACseq - MTG/1149689567-fragments.tsv.gz
# File (syn31149089): snATACseq - MTG/1149689567-fragments.tsv.gz.tbi
# File (syn31148169): snATACseq - MTG/1149689568-fragments.tsv.gz
# File (syn31149071): snATACseq - MTG/1149689568-fragments.tsv.gz.tbi
# File (syn31148767): snATACseq - MTG/1149689569-fragments.tsv.gz
# File (syn31149090): snATACseq - MTG/1149689569-fragments.tsv.gz.tbi
# File (syn31148458): snATACseq - MTG/1149689570-fragments.tsv.gz
# File (syn31149093): snATACseq - MTG/1149689570-fragments.tsv.gz.tbi
# File (syn31148552): snATACseq - MTG/1149773119-fragments.tsv.gz
# File (syn31149105): snATACseq - MTG/1149773119-fragments.tsv.gz.tbi
# File (syn31148701): snATACseq - MTG/1149773121-fragments.tsv.gz
# File (syn31149098): snATACseq - MTG/1149773121-fragments.tsv.gz.tbi
# File (syn31148736): snATACseq - MTG/1149773124-fragments.tsv.gz
# File (syn31149099): snATACseq - MTG/1149773124-fragments.tsv.gz.tbi
# File (syn31148989): snATACseq - MTG/1149773127-fragments.tsv.gz
# File (syn31149123): snATACseq - MTG/1149773127-fragments.tsv.gz.tbi
# File (syn31148641): snATACseq - MTG/1149773128-fragments.tsv.gz
# File (syn31149101): snATACseq - MTG/1149773128-fragments.tsv.gz.tbi
# File (syn31148585): snATACseq - MTG/1149773129-fragments.tsv.gz
# File (syn31149094): snATACseq - MTG/1149773129-fragments.tsv.gz.tbi
# File (syn31148801): snATACseq - MTG/1149773130-fragments.tsv.gz
# File (syn31149096): snATACseq - MTG/1149773130-fragments.tsv.gz.tbi
# File (syn31148827): snATACseq - MTG/1149773131-fragments.tsv.gz
# File (syn31149118): snATACseq - MTG/1149773131-fragments.tsv.gz.tbi
# File (syn31148850): snATACseq - MTG/1152530383-fragments.tsv.gz
# File (syn31149103): snATACseq - MTG/1152530383-fragments.tsv.gz.tbi
# File (syn31148830): snATACseq - MTG/1152618568-fragments.tsv.gz
# File (syn31149100): snATACseq - MTG/1152618568-fragments.tsv.gz.tbi
# File (syn31148844): snATACseq - MTG/1152618570-fragments.tsv.gz
# File (syn31149097): snATACseq - MTG/1152618570-fragments.tsv.gz.tbi
# File (syn31148854): snATACseq - MTG/1152618571-fragments.tsv.gz
# File (syn31149095): snATACseq - MTG/1152618571-fragments.tsv.gz.tbi
# File (syn31148838): snATACseq - MTG/1152618572-fragments.tsv.gz
# File (syn31149107): snATACseq - MTG/1152618572-fragments.tsv.gz.tbi
# File (syn31148960): snATACseq - MTG/1153896349-fragments.tsv.gz
# File (syn31149106): snATACseq - MTG/1153896349-fragments.tsv.gz.tbi
# File (syn31148935): snATACseq - MTG/1153896350-fragments.tsv.gz
# File (syn31149108): snATACseq - MTG/1153896350-fragments.tsv.gz.tbi
# File (syn31148924): snATACseq - MTG/1153896351-fragments.tsv.gz
# File (syn31149115): snATACseq - MTG/1153896351-fragments.tsv.gz.tbi
# File (syn31148861): snATACseq - MTG/1153896887-fragments.tsv.gz
# File (syn31149102): snATACseq - MTG/1153896887-fragments.tsv.gz.tbi
# File (syn31148870): snATACseq - MTG/1153896888-fragments.tsv.gz
# File (syn31149110): snATACseq - MTG/1153896888-fragments.tsv.gz.tbi
# File (syn31148948): snATACseq - MTG/1153896889-fragments.tsv.gz
# File (syn31149111): snATACseq - MTG/1153896889-fragments.tsv.gz.tbi
# File (syn31148879): snATACseq - MTG/1155512003-fragments.tsv.gz
# File (syn31149117): snATACseq - MTG/1155512003-fragments.tsv.gz.tbi
# File (syn31148886): snATACseq - MTG/1155512005-fragments.tsv.gz
# File (syn31149114): snATACseq - MTG/1155512005-fragments.tsv.gz.tbi
# File (syn31148909): snATACseq - MTG/1157000752-fragments.tsv.gz
# File (syn31149121): snATACseq - MTG/1157000752-fragments.tsv.gz.tbi
# File (syn31148974): snATACseq - MTG/1158586576-fragments.tsv.gz
# File (syn31149120): snATACseq - MTG/1158586576-fragments.tsv.gz.tbi
# File (syn31149004): snATACseq - MTG/1158586577-fragments.tsv.gz
# File (syn31149125): snATACseq - MTG/1158586577-fragments.tsv.gz.tbi
# File (syn31149033): snATACseq - MTG/1158586578-fragments.tsv.gz
# File (syn31149122): snATACseq - MTG/1158586578-fragments.tsv.gz.tbi

# %%
metadata = pd.DataFrame(annotations)
metadata.to_csv(dat_dir+'seaad_mtg_fragments_metadata.csv')

# %% [markdown]
# ## **[Gabitto et. al. 2021](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10246227/) (Dorso Lateral Prefrontal Cortex)**

# %%
adata = sc.read_h5ad('../data/raw/SEA-AD/DLPFC/RNASeq/SEAAD_DLPFC_RNAseq_final-nuclei.2024-02-13.h5ad')

adata.obs['cell_type'] = adata.obs['Subclass'].copy()
adata.obs['cell_type'] = adata.obs['cell_type'].astype(str)
adata.obs.loc[adata.obs['Class'].str.startswith("Neuronal:"), 'cell_type'] = adata.obs['Class'][adata.obs['Class'].str.startswith("Neuronal:")].map({"Neuronal: Glutamatergic": "Excitatory",
                                                                "Neuronal: GABAergic": "Inhibitory"})

adata.obs.loc[adata.obs.cell_type=='Microglia-PVM', 'cell_type'] = 'Microglia'
adata.obs['cell_type'] = adata.obs['cell_type'].astype('category')

adata.layers['counts'] = adata.layers['nUMIs']

# %%
dat_dir = f'../data/raw/seaad_pfc/anndata/rna/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)

# Define the columns to convert for obs and var
obs_columns_to_convert = None
var_columns_to_convert = None

# Define the SCE objects and their corresponding file paths

file_paths = {
    'Excitatory': "../data/raw/seaad_pfc/anndata/rna/excitatory_raw_anndata.h5ad",
    'Inhibitory': "../data/raw/seaad_pfc/anndata/rna/inhibitory_raw_anndata.h5ad",
    'Astrocyte': "../data/raw/seaad_pfc/anndata/rna/astrocyte_raw_anndata.h5ad",
    'Microglia': "../data/raw/seaad_pfc/anndata/rna/microglia_raw_anndata.h5ad",
    'Oligodendrocyte': "../data/raw/seaad_pfc/rna/anndata/oligodendrocyte_raw_anndata.h5ad",
    'OPC': "../data/raw/seaad_pfc/anndata/rna/opc_raw_anndata.h5ad",
    'Endothelial': "../data/raw/seaad_pfc/rna/anndata/endothelial_raw_anndata.h5ad",
    'VLMC': "../data/raw/seaad_pfc/anndata/rna/vlmc_raw_anndata.h5ad"
}


for sce_name in adata.obs.cell_type.unique():
    sce_obj = adata[adata.obs.cell_type==sce_name]
    convert_columns_to_string(sce_obj, obs_cols=obs_columns_to_convert, var_cols=var_columns_to_convert)
    save_anndata(sce_obj, file_paths[sce_name])   
    # create_minimal_adata(sce_obj, '/'.join(file_paths[sce_name].split('/')[:-1] + ['minimal/minimal_'+file_paths[sce_name].split('/')[-1]]))

# %% [markdown]
# ## **[Gabitto et. al. 2021](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10246227/) (Dorso Lateral Prefrontal Cortex - Raw Fragments File)**

# %%
token = "eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..pXoRdUHD1rXCvalb9RtQbvcNal0mGsHZM77YZ6imofGnEe-ehPkL4CbTFFJLEmgv-PvdCcrc5xRjY0oy8lO8xbw-CgUyiCSYAWw8QJZk-7ctAnHljMRG5SpBW5PFlWIVbHUe8G0hpfZusp3CNxUOMoiFrWysktPR1zQUhSv-dvDDDj1qePcjAllhLSTQiyAOmhJ20VJT_y6rMLWf5kkTpOwyDPgHUT9iO2nECkyPq9nVhd8aopTbFUsH9L6MRmIaWgDJi4C0spu9cUvhrIvJceWdu9lWLS1AaDdXk-I3SDeiyIMk8_YLgfoELLi_36OE-6bsB3D0XbhArWgmizpXqg"
syn = synapseclient.login(authToken=token)

dat_dir = '/Volumes/Seagate/SEA-AD/DLPFC/ATACseq/fragments/' #f'../data/raw/SEA-AD/DLPFC/ATACseq/fragments/'

if not os.path.exists(dat_dir):
    os.makedirs(dat_dir)
# Out:
# Welcome, tadeoye_usf!

# %%
syn.get_annotations('syn52047001')
# Out:
# {'sex': ['female'],
#  'assay': ['snATACSeq'],
#  'grant': ['U19AG060909'],
#  'organ': ['brain'],
#  'study': ['SEA-AD'],
#  'tissue': ['dorsolateral prefrontal cortex'],
#  'runType': ['pairedEnd'],
#  'species': ['Human'],
#  'dataType': ['epigenetics'],
#  'platform': ['IlluminaNovaseq6000'],
#  'consortium': ['CDCP'],
#  'fileFormat': ['tsv'],
#  'isMultiome': [False],
#  'readLength': ['50bp'],
#  'specimenID': ['M2AT_220207_216_A01'],
#  'dataSubtype': ['processed'],
#  'individualID': ['H20.33.011'],
#  'resourceType': ['experimentalData'],
#  'isModelSystem': [False],
#  'isMultiSpecimen': [False],
#  'nucleicAcidSource': ['single nucleus']}

# %%
my_project_id = 'syn51792377'
fragment_ids = []

annotations = {key: [] for key in syn.get_annotations('syn52047001').keys()}
annotations['synapseID'] = []
annotations['fileID'] = []

for directory_path, directory_names, file_name in synapseutils.walk(syn=syn, synId=my_project_id, includeTypes=["file"]):
    for directory_name in directory_names:
        print(f"Directory ({directory_name[1]}): {directory_path[0]}/{directory_name[0]}")

    for file in file_name:

        # download fragment files
        if file[0].endswith('.tsv.gz'):
            print(f"File ({file[1]}): {directory_path[0]}/{file[0]}")

            # include annotations for metadata construction
            for key in syn.get_annotations(file[1]):
                annotations[key].append(syn.get_annotations(file[1])[key][0])
            annotations['synapseID'].append(file[1])
            annotations['fileID'].append(file[0].split('_')[0])
            fragment_ids.append(file[1])

            fragment_ids.append(file[1])
            if file[0] not in os.listdir(dat_dir):
                fragment_files = synapseutils.syncFromSynapse(syn, file[1], path=dat_dir, manifest=all)
            
        # download index files
        elif file[0].endswith('.tsv.gz.tbi'):
            print(f"File ({file[1]}): {directory_path[0]}/{file[0]}")
            if file[0] not in os.listdir(dat_dir):
                fragment_files = synapseutils.syncFromSynapse(syn, file[1], path=dat_dir, manifest='root')
# Out:
# File (syn52047001): snATACseq - DLPFC/1160415290_outs_fragments.tsv.gz
# File (syn52046999): snATACseq - DLPFC/1160415290_outs_fragments.tsv.gz.tbi
# File (syn52047002): snATACseq - DLPFC/1160415291_outs_fragments.tsv.gz
# File (syn52047000): snATACseq - DLPFC/1160415291_outs_fragments.tsv.gz.tbi
# File (syn52047004): snATACseq - DLPFC/1160415292_outs_fragments.tsv.gz
# File (syn52047003): snATACseq - DLPFC/1160415292_outs_fragments.tsv.gz.tbi
# File (syn52047040): snATACseq - DLPFC/1161484004_outs_fragments.tsv.gz
# File (syn52047039): snATACseq - DLPFC/1161484004_outs_fragments.tsv.gz.tbi
# File (syn52047046): snATACseq - DLPFC/1161484005_outs_fragments.tsv.gz
# File (syn52047044): snATACseq - DLPFC/1161484005_outs_fragments.tsv.gz.tbi
# File (syn52047026): snATACseq - DLPFC/1161484006_outs_fragments.tsv.gz
# File (syn52047025): snATACseq - DLPFC/1161484006_outs_fragments.tsv.gz.tbi
# File (syn52047030): snATACseq - DLPFC/1161484007_outs_fragments.tsv.gz
# File (syn52047029): snATACseq - DLPFC/1161484007_outs_fragments.tsv.gz.tbi
# File (syn52047042): snATACseq - DLPFC/1161484008_outs_fragments.tsv.gz
# File (syn52047041): snATACseq - DLPFC/1161484008_outs_fragments.tsv.gz.tbi
# File (syn52047053): snATACseq - DLPFC/1162824600_outs_fragments.tsv.gz
# File (syn52047052): snATACseq - DLPFC/1162824600_outs_fragments.tsv.gz.tbi
# File (syn52047045): snATACseq - DLPFC/1162824601_outs_fragments.tsv.gz
# File (syn52047043): snATACseq - DLPFC/1162824601_outs_fragments.tsv.gz.tbi
# File (syn52047671): snATACseq - DLPFC/1162824602_outs_fragments.tsv.gz
# File (syn52047047): snATACseq - DLPFC/1162824602_outs_fragments.tsv.gz.tbi
# File (syn52047049): snATACseq - DLPFC/1162824604_outs_fragments.tsv.gz
# File (syn52047048): snATACseq - DLPFC/1162824604_outs_fragments.tsv.gz.tbi
# File (syn52047051): snATACseq - DLPFC/1162824605_outs_fragments.tsv.gz
# File (syn52047050): snATACseq - DLPFC/1162824605_outs_fragments.tsv.gz.tbi
# File (syn52047055): snATACseq - DLPFC/1164430758_outs_fragments.tsv.gz
# File (syn52047054): snATACseq - DLPFC/1164430758_outs_fragments.tsv.gz.tbi
# File (syn52047069): snATACseq - DLPFC/1164430759_outs_fragments.tsv.gz
# File (syn52047068): snATACseq - DLPFC/1164430759_outs_fragments.tsv.gz.tbi
# File (syn52047067): snATACseq - DLPFC/1164430760_outs_fragments.tsv.gz
# File (syn52047066): snATACseq - DLPFC/1164430760_outs_fragments.tsv.gz.tbi
# File (syn52047077): snATACseq - DLPFC/1166017189_outs_fragments.tsv.gz
# File (syn52047075): snATACseq - DLPFC/1166017189_outs_fragments.tsv.gz.tbi
# File (syn52047080): snATACseq - DLPFC/1166017191_outs_fragments.tsv.gz
# File (syn52047079): snATACseq - DLPFC/1166017191_outs_fragments.tsv.gz.tbi
# File (syn52047082): snATACseq - DLPFC/1166017192_outs_fragments.tsv.gz
# File (syn52047081): snATACseq - DLPFC/1166017192_outs_fragments.tsv.gz.tbi
# File (syn52047073): snATACseq - DLPFC/1166017193_outs_fragments.tsv.gz
# File (syn52047072): snATACseq - DLPFC/1166017193_outs_fragments.tsv.gz.tbi
# File (syn52047078): snATACseq - DLPFC/1166017194_outs_fragments.tsv.gz
# File (syn52047076): snATACseq - DLPFC/1166017194_outs_fragments.tsv.gz.tbi
# File (syn52047071): snATACseq - DLPFC/1166017195_outs_fragments.tsv.gz
# File (syn52047070): snATACseq - DLPFC/1166017195_outs_fragments.tsv.gz.tbi
# File (syn52047678): snATACseq - DLPFC/1167718972_outs_fragments.tsv.gz
# File (syn52047083): snATACseq - DLPFC/1167718972_outs_fragments.tsv.gz.tbi
# File (syn52047085): snATACseq - DLPFC/1167718973_outs_fragments.tsv.gz
# File (syn52047084): snATACseq - DLPFC/1167718973_outs_fragments.tsv.gz.tbi
# File (syn52047087): snATACseq - DLPFC/1169097245_outs_fragments.tsv.gz
# File (syn52047086): snATACseq - DLPFC/1169097245_outs_fragments.tsv.gz.tbi
# File (syn52047094): snATACseq - DLPFC/1169097247_outs_fragments.tsv.gz
# File (syn52047093): snATACseq - DLPFC/1169097247_outs_fragments.tsv.gz.tbi
# File (syn52047089): snATACseq - DLPFC/1169097248_outs_fragments.tsv.gz
# File (syn52047088): snATACseq - DLPFC/1169097248_outs_fragments.tsv.gz.tbi
# File (syn52047008): snATACseq - DLPFC/1170306930_outs_fragments.tsv.gz
# File (syn52047007): snATACseq - DLPFC/1170306930_outs_fragments.tsv.gz.tbi
# File (syn52047012): snATACseq - DLPFC/1170306932_outs_fragments.tsv.gz
# File (syn52047009): snATACseq - DLPFC/1170306932_outs_fragments.tsv.gz.tbi
# File (syn52047015): snATACseq - DLPFC/1170306933_outs_fragments.tsv.gz
# File (syn52047013): snATACseq - DLPFC/1170306933_outs_fragments.tsv.gz.tbi
# File (syn52047016): snATACseq - DLPFC/1170306934_outs_fragments.tsv.gz
# File (syn52047014): snATACseq - DLPFC/1170306934_outs_fragments.tsv.gz.tbi
# File (syn52047022): snATACseq - DLPFC/1170306935_outs_fragments.tsv.gz
# File (syn52047021): snATACseq - DLPFC/1170306935_outs_fragments.tsv.gz.tbi
# File (syn52047018): snATACseq - DLPFC/1170306936_outs_fragments.tsv.gz
# File (syn52047017): snATACseq - DLPFC/1170306936_outs_fragments.tsv.gz.tbi
# File (syn52047020): snATACseq - DLPFC/1170306937_outs_fragments.tsv.gz
# File (syn52047019): snATACseq - DLPFC/1170306937_outs_fragments.tsv.gz.tbi
# File (syn52047037): snATACseq - DLPFC/1170306938_outs_fragments.tsv.gz
# File (syn52047036): snATACseq - DLPFC/1170306938_outs_fragments.tsv.gz.tbi
# File (syn52047024): snATACseq - DLPFC/1170306939_outs_fragments.tsv.gz
# File (syn52047023): snATACseq - DLPFC/1170306939_outs_fragments.tsv.gz.tbi
# File (syn52047006): snATACseq - DLPFC/1170306940_outs_fragments.tsv.gz
# File (syn52047005): snATACseq - DLPFC/1170306940_outs_fragments.tsv.gz.tbi
# File (syn52047096): snATACseq - DLPFC/1170314859_outs_fragments.tsv.gz
# File (syn52047095): snATACseq - DLPFC/1170314859_outs_fragments.tsv.gz.tbi
# File (syn52047100): snATACseq - DLPFC/1171816352_outs_fragments.tsv.gz
# File (syn52047099): snATACseq - DLPFC/1171816352_outs_fragments.tsv.gz.tbi
# File (syn52047098): snATACseq - DLPFC/1171816353_outs_fragments.tsv.gz
# File (syn52047097): snATACseq - DLPFC/1171816353_outs_fragments.tsv.gz.tbi
# File (syn52047102): snATACseq - DLPFC/1173790248_outs_fragments.tsv.gz
# File (syn52047101): snATACseq - DLPFC/1173790248_outs_fragments.tsv.gz.tbi
# File (syn52047104): snATACseq - DLPFC/1173790249_outs_fragments.tsv.gz
# File (syn52047103): snATACseq - DLPFC/1173790249_outs_fragments.tsv.gz.tbi
# File (syn52047107): snATACseq - DLPFC/1210475988_outs_fragments.tsv.gz
# File (syn52047106): snATACseq - DLPFC/1210475988_outs_fragments.tsv.gz.tbi
# File (syn52047109): snATACseq - DLPFC/1210475989_outs_fragments.tsv.gz
# File (syn52047108): snATACseq - DLPFC/1210475989_outs_fragments.tsv.gz.tbi

# %%
metadata = pd.DataFrame(annotations)
metadata.to_csv(dat_dir+'seaad_pfc_fragments_metadata.csv')
